# %%
import pandas as pd
import numpy as np
import re
from string import ascii_letters, digits
import cleaning_dicts
import os

# %%
print(cleaning_dicts.clean_team_pff)
# Out:
# {'arz': 'ari', 'blt': 'bal', 'clv': 'cle', 'hst': 'hou', 'la': 'lar', 'sd': 'lac', 'sl': 'lar'}

# %%
cur_dir = os.path.abspath(os.getcwd())
cur_week_folder = 'nfl_week_4'
cur_week = '4'
int_cur_week = 4

# %%
print(cur_dir)
# Out:
# /media/tom/Windows/Users/booth/Documents/spreads/spreads_2021

# %%
spreads = pd.read_csv(cur_dir+"/current_season_data/"+cur_week_folder+'/spreadspoke_w'+cur_week+'.csv')
weather = pd.read_csv(cur_dir+"/weather/"+'/weather_hist_w'+cur_week+'.csv')
fo = pd.read_csv(cur_dir+"/other_data/"+'/fo_final.csv')

# %%
def raiders(df):
    if 'oak' in str(df.away_matchup_id) and '2020' in str(df.away_matchup_id):
        return df.away_matchup_id.replace("oak","lv")
    else:
        return df.away_matchup_id
weather['away_matchup_id'] = weather.apply(lambda df: raiders(df), axis=1)

# %% [markdown]
# ### Read in raw datasets

# %%
qb_standard_2019 = pd.read_csv(cur_dir+'/historic_data'+'/qb_standard_hist.csv')
oline_2019 = pd.read_csv(cur_dir+'/historic_data'+'/ol_standard_hist.csv')
#qb_adj_2019 = pd.read_csv(cur_dir+'historic_data'+'/qb_adjusted_hist_16.csv')
rush_std_2019 = pd.read_csv(cur_dir+'/historic_data'+'/rush_standard_hist.csv')
rec_std_2019 = pd.read_csv(cur_dir+'/historic_data'+'/rec_standard_hist.csv')
def_standard_2019 = pd.read_csv(cur_dir+'/historic_data'+'/def_standard_hist.csv')

qb_standard = qb_standard_2019[~qb_standard_2019['player'].isnull()]
oline = oline_2019[~oline_2019['player'].isnull()]
#qb_adj_2019 = qb_adj_2019[~qb_adj_2019['player'].isnull()]
rush_std = rush_std_2019[~rush_std_2019['player'].isnull()]
rec_std = rec_std_2019[~rec_std_2019['player'].isnull()]
def_standard = def_standard_2019[~def_standard_2019['player'].isnull()]


qb_standard_2021 = pd.read_csv(cur_dir+'/historic_data'+'/qb_standard_hist_w'+cur_week+'.csv')
oline_2021 = pd.read_csv(cur_dir+'/historic_data'+'/ol_standard_hist_w'+cur_week+'.csv')
#qb_adj_2019 = pd.read_csv(cur_dir+'historic_data'+'/qb_adjusted_hist_16.csv')
rush_std_2021 = pd.read_csv(cur_dir+'/historic_data'+'/rush_standard_hist_w'+cur_week+'.csv')
rec_std_2021 = pd.read_csv(cur_dir+'/historic_data'+'/rec_standard_hist_w'+cur_week+'.csv')
def_standard_2021 = pd.read_csv(cur_dir+'/historic_data'+'/def_standard_hist_w'+cur_week+'.csv')

qb_standard_2021 = qb_standard_2021[~qb_standard_2021['player'].isnull()]
oline_2021 = oline_2021[~oline_2021['player'].isnull()]
#qb_adj_2019 = qb_adj_2019[~qb_adj_2019['player'].isnull()]
rush_std_2021 = rush_std_2021[~rush_std_2021['player'].isnull()]
rec_std_2021 = rec_std_2021[~rec_std_2021['player'].isnull()]
def_standard_2021 = def_standard_2021[~def_standard_2021['player'].isnull()]

qb_standard = pd.concat([qb_standard, qb_standard_2021], axis=0)
oline = pd.concat([oline, oline_2021], axis=0)
#qb_adj = pd.concat([qb_adj, qb_adj_old], axis=0)
rush_std = pd.concat([rush_std, rush_std_2021], axis=0)
rec_std = pd.concat([rec_std, rec_std_2021], axis=0)
def_standard = pd.concat([def_standard, def_standard_2021], axis=0)

qb_standard.reset_index(inplace=True, drop=True)
oline.reset_index(inplace=True, drop=True)
rush_std.reset_index(inplace=True, drop=True)
rec_std.reset_index(inplace=True, drop=True)
def_standard.reset_index(inplace=True, drop=True)

# %%
qb_standard.head().T
# Out:
#                                     0           1              2  \
# player                 Peyton Manning  Alex Smith  Jake Delhomme
# player_id                         327        2218            303
# position                           QB          QB             QB
# team_name                         IND          SF            CAR
# player_game_count                   1           1              1
# accuracy_percent                 68.3        69.4           56.8
# aimed_passes                       41          36             37
# attempts                           41          40             39
# avg_depth_of_target              10.1         8.8           10.1
# avg_time_to_throw                2.71         2.9           2.53
# bats                                0           0              2
# big_time_throws                     3           2              0
# btt_rate                          7.1         4.7              0
# completion_percent                 61        57.5           53.8
# completions                        25          23             21
# declined_penalties                  0           0              0
# def_gen_pressures                  18          10             16
# drop_rate                        10.7           8              0
# dropbacks                          42          41             43
# drops                               3           2              0
# first_downs                        17          10             11
# franchise_id                       14          28              5
# grades_hands_fumble              79.5        79.6           42.1
# grades_offense                   77.6        54.7           39.1
# grades_pass                      75.9        54.6           40.3
# grades_run                        NaN         NaN            NaN
# hit_as_threw                        0           1              0
# interceptions                       1           0              1
# passing_snaps                      43          44             45
# penalties                           0           0              0
# pressure_to_sack_rate             5.6          10             25
# qb_rating                        78.9        88.3           56.1
# sack_percent                      2.4         2.4            9.3
# sacks                               1           1              4
# scrambles                           0           0              0
# spikes                              0           2              0
# thrown_aways                        0           1              0
# touchdowns                          1           1              0
# turnover_worthy_plays               3           2              4
# twp_rate                            7         4.5            8.9
# yards                             276         288            186
# ypa                               6.7         7.2            4.8
# week                                1           1              1
# year                             2006        2006           2006
#
#                                    3                 4
# player                 Kerry Collins  Daunte Culpepper
# player_id                        115               446
# position                          QB                QB
# team_name                        TEN               MIA
# player_game_count                  1                 1
# accuracy_percent                72.4              58.8
# aimed_passes                      29                34
# attempts                          38                37
# avg_depth_of_target              8.8               8.9
# avg_time_to_throw               2.63               2.7
# bats                               5                 0
# big_time_throws                    1                 1
# btt_rate                         2.5               2.6
# completion_percent              44.7              48.6
# completions                       17                18
# declined_penalties                 0                 0
# def_gen_pressures                 11                20
# drop_rate                         19                10
# dropbacks                         40                42
# drops                              4                 2
# first_downs                       12                13
# franchise_id                      31                17
# grades_hands_fumble             79.3              79.8
# grades_offense                  63.9              48.6
# grades_pass                       63              50.3
# grades_run                       NaN              52.3
# hit_as_threw                       2                 1
# interceptions                      2                 2
# passing_snaps                     42                44
# penalties                          1                 0
# pressure_to_sack_rate           18.2                15
# qb_rating                       41.9              49.6
# sack_percent                       5               7.1
# sacks                              2                 3
# scrambles                          0                 2
# spikes                             0                 0
# thrown_aways                       2                 2
# touchdowns                         0                 0
# turnover_worthy_plays              2                 2
# twp_rate                         4.8               4.5
# yards                            223               262
# ypa                              5.9               7.1
# week                               1                 1
# year                            2006              2006

# %%
qb_standard.drop('player_id', axis=1, inplace=True)
oline.drop('player_id', axis=1, inplace=True)
rush_std.drop('player_id', axis=1, inplace=True)
rec_std.drop('player_id', axis=1, inplace=True)
def_standard.drop('player_id', axis=1, inplace=True)

# %% [markdown]
# ### Bring them the data together and remove duplicate captures

# %%
qb_standard.drop_duplicates(subset=['player','year','week'], keep='first', inplace=True)
oline.drop_duplicates(subset=['player','year','week'], keep='first', inplace=True)
#qb_adj.drop_duplicates(subset=['player','year','week'], keep='first', inplace=True)
rush_std.drop_duplicates(subset=['player','year','week'], keep='first', inplace=True)
rec_std.drop_duplicates(subset=['player','year','week'], keep='first', inplace=True)
def_standard.drop_duplicates(subset=['player','year','week'], keep='first', inplace=True)

def clean_str_nan(nData):
    nData.replace(["NaN", 'NaT'], np.nan, inplace = True)
    nData=nData[pd.notnull(nData['player'])]
    #nData=nData.dropna(thresh=10)
    nData['year'] = nData['year'].astype(int)
    nData['week'] = nData['week'].astype(int)
    return nData

rush_std = clean_str_nan(rush_std)
qb_standard =clean_str_nan(qb_standard)
oline=clean_str_nan(oline)
#qb_adj=clean_str_nan(qb_adj)
rec_std=clean_str_nan(rec_std)
def_standard=clean_str_nan(def_standard)

# %%
def clean_name(df):
    result = ''.join(c for c in df['player'] if c.isalpha())
    return result.lower()

# %%
fo.columns
# Out:
# Index(['team_id', 'year', 'week', 'team', 'w-l', 'off_dvoa_rank', 'off_dvoa',
#        'off_weight_dvoa_rank', 'off_weight_dvoa', 'pass_off_rank', 'pass_off',
#        'rush_off_rank', 'rush_off', 'def_dvoa_rank', 'def_dvoa',
#        'def_weight_dvoa_rank', 'def_weight_dvoa', 'pass_def_rank', 'pass_def',
#        'rush_def_rank', 'rush_def'],
#       dtype='object')

# %%
def raiders_fo(df):
    if 'oak' in str(df.team) and '2020' in str(df.year):
        return df.team_id.str.replace("oak_","lv_")
    elif 'oak' in str(df.team) and '2021' in str(df.year):
        return df.team_id.str.replace("oak_","lv_")
    else:
        return str(df.team_id)

# %%
fo_2021 = pd.read_csv(cur_dir+'/football_outsiders/fo_final.csv')
fo_pp = pd.read_csv(cur_dir+'/current_season_data/'+cur_week_folder+'/fo_clean_pp_w'+cur_week+'.csv')
fo = pd.concat([fo, fo_2021, fo_pp], axis=0)

fo['team_id'] = fo.apply(lambda df: raiders_fo(df), axis=1)
#fo['team_id']=fo['team_id'].str.replace("oak_","lv_")

fo = fo.sort_values(by=["team","year","week"], ascending=[True, True, True])
#data=data.fillna(data.mean())
def running_diff(arr, N):
    return np.array([arr[i] - arr[i-N] for i in range(N, len(arr))])

fo['off_dvoa_momentum'] = np.hstack((fo['off_dvoa_rank'].values[:3], running_diff(fo['off_dvoa_rank'].values, 3)))
fo['off_wt_dvoa_momentum'] = np.hstack((fo['off_weight_dvoa_rank'].values[:3], running_diff(fo['off_weight_dvoa_rank'].values, 3)))
fo['pass_off_dvoa_momentum'] = np.hstack((fo['pass_off_rank'].values[:3], running_diff(fo['pass_off_rank'].values, 3)))
fo['rush_off_dvoa_momentum'] = np.hstack((fo['rush_off_rank'].values[:3], running_diff(fo['rush_off_rank'].values, 3)))

fo['def_dvoa_momentum'] = np.hstack((fo['def_dvoa_rank'].values[:3], running_diff(fo['def_dvoa_rank'].values, 3)))
fo['def_wt_dvoa_momentum'] = np.hstack((fo['def_weight_dvoa_rank'].values[:3], running_diff(fo['def_weight_dvoa_rank'].values, 3)))
fo['pass_def_dvoa_momentum'] = np.hstack((fo['pass_def_rank'].values[:3], running_diff(fo['pass_def_rank'].values, 3)))
fo['rush_dvoa_momentum'] = np.hstack((fo['rush_def_rank'].values[:3], running_diff(fo['rush_def_rank'].values, 3)))

num_cols = fo.select_dtypes(include=[np.number]).columns.tolist()
ids = pd.DataFrame(fo.select_dtypes(exclude=[np.number])).reset_index(drop=True)
roll3 = fo.groupby(['team','year'])[num_cols].apply(lambda x : x.shift(+1)).reset_index(drop=True)
fo_roll = pd.concat([ids, roll3], axis=1)

# %%
fo_roll.tail().T
# Out:
#                                8283        8284        8285        8286  \
# team_id                 was_2020_17  was_2021_1  was_2021_2  was_2021_3
# team                            was         was         was         was
# w-l                             7-9         0-1         1-1         1-2
# year                           2020         NaN        2021        2021
# week                             16         NaN           1           2
# off_dvoa_rank                    30         NaN          24           9
# off_dvoa                      -20.4         NaN       -12.2        13.1
# off_weight_dvoa_rank             29         NaN          24           9
# off_weight_dvoa               -18.6         NaN       -12.2        13.1
# pass_off_rank                    32         NaN          17          15
# pass_off                      -25.2         NaN        24.1        29.8
# rush_off_rank                    11         NaN          27           9
# rush_off                       -3.9         NaN       -36.5        -4.9
# def_dvoa_rank                     2         NaN          12          18
# def_dvoa                      -17.8         NaN          -9         1.6
# def_weight_dvoa_rank              4         NaN          12          18
# def_weight_dvoa               -18.5         NaN          -9         1.6
# pass_def_rank                     2         NaN          11          16
# pass_def                      -17.8         NaN         0.2         8.4
# rush_def_rank                    13         NaN          15          21
# rush_def                      -17.8         NaN       -23.6        -8.2
# off_dvoa_momentum                 2         NaN          -6         -21
# off_wt_dvoa_momentum              2         NaN          -5         -20
# pass_off_dvoa_momentum            2         NaN         -15         -17
# rush_off_dvoa_momentum           -6         NaN          15          -2
# def_dvoa_momentum                -2         NaN           9          16
# def_wt_dvoa_momentum              0         NaN           8          14
# pass_def_dvoa_momentum           -1         NaN           9          14
# rush_dvoa_momentum                3         NaN           2           8
#
#                               8287
# team_id                 was_2021_4
# team                           was
# w-l                            1-2
# year                          2021
# week                             3
# off_dvoa_rank                   20
# off_dvoa                      -4.3
# off_weight_dvoa_rank            20
# off_weight_dvoa               -4.3
# pass_off_rank                   20
# pass_off                        12
# rush_off_rank                   28
# rush_off                     -23.5
# def_dvoa_rank                   29
# def_dvoa                      15.6
# def_weight_dvoa_rank            29
# def_weight_dvoa               15.6
# pass_def_rank                   28
# pass_def                      32.9
# rush_def_rank                   20
# rush_def                      -9.9
# off_dvoa_momentum              -12
# off_wt_dvoa_momentum           -12
# pass_off_dvoa_momentum         -12
# rush_off_dvoa_momentum          14
# def_dvoa_momentum               26
# def_wt_dvoa_momentum            26
# pass_def_dvoa_momentum          26
# rush_dvoa_momentum               9

# %% [markdown]
# def rolling_fos(data=None, roll_value=None, roll_type=None):
#
#     """
#         Args:
#         data: input pandas dataframe to be rolled
#         roll_value: input the number, default is three ## we will need to modify the function if we want more ##
#         roll_type: 'mean','std', or 'var' are the only options at the point
#         ## assign mean for a given team & year as opposed to the entire dataset
#
#     """
#
#     data = data.sort_values(by=["team","year","week"], ascending=[True, True, True])
#     #data=data.fillna(data.mean())
#     num_cols = data.select_dtypes(include=[np.number]).columns.tolist()
#     ids = pd.DataFrame(data.select_dtypes(exclude=[np.number])).reset_index(drop=True)
#
#     if roll_type == 'mean':
#         #roll5 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
#         #roll4 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
#         roll3 = data.groupby(['team','year'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
#         roll2 = data.groupby(['team','year'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-1).mean())
#         roll1 = data.groupby(['team','year'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-2).mean())
#         roll3 = pd.DataFrame(roll3.combine_first(roll2).combine_first(roll1)).reset_index(drop=True)
#         df = pd.concat([ids, roll3], axis=1)
#     return df
#
# fo_roll = rolling_fos(data=fo, roll_value=3, roll_type='mean')
# fo_roll.head().T

# %% [markdown]
# ### Clean Spread Data

# %%
spreads['schedule_season']=spreads['schedule_season'].apply(int)
spreads['schedule_week']=spreads['schedule_week'].apply(int)
spreads.head().T
# Out:
#                                       0                   1  \
# schedule_date                 9/10/2006           9/10/2006
# schedule_season                    2006                2006
# schedule_week                         1                   1
# schedule_playoff                  False               False
# team_home            Kansas City Chiefs     New York Giants
# team_home_abb                        KC                 NYG
# score_home                           10                  21
# score_away                           23                  26
# team_away            Cincinnati Bengals  Indianapolis Colts
# away_team_abb                       CIN                 IND
# team_favorite_id                    CIN                 IND
# spread_favorite                    -1.5                  -3
# over_under_line                    49.5                47.5
# stadium               Arrowhead Stadium      Giants Stadium
# stadium_neutral                   False               False
# weather_temperature                  69                  72
# weather_wind_mph                     11                  10
# weather_humidity                     83                  59
# weather_detail                      NaN                 NaN
#
#                                      2                              3  \
# schedule_date                9/10/2006                      9/10/2006
# schedule_season                   2006                           2006
# schedule_week                        1                              1
# schedule_playoff                 False                          False
# team_home               St. Louis Rams              Arizona Cardinals
# team_home_abb                      LAR                            ARI
# score_home                          18                             34
# score_away                          10                             27
# team_away               Denver Broncos            San Francisco 49ers
# away_team_abb                      DEN                             SF
# team_favorite_id                   DEN                            ARI
# spread_favorite                   -3.5                           -9.5
# over_under_line                     46                             44
# stadium              Edward Jones Dome  University of Phoenix Stadium
# stadium_neutral                  False                          False
# weather_temperature                 72                             72
# weather_wind_mph                     0                              0
# weather_humidity                   NaN                            NaN
# weather_detail                    DOME                           DOME
#
#                                     4
# schedule_date               9/10/2006
# schedule_season                  2006
# schedule_week                       1
# schedule_playoff                False
# team_home               Detroit Lions
# team_home_abb                     DET
# score_home                          6
# score_away                          9
# team_away            Seattle Seahawks
# away_team_abb                     SEA
# team_favorite_id                  SEA
# spread_favorite                    -6
# over_under_line                    44
# stadium                    Ford Field
# stadium_neutral                 False
# weather_temperature                72
# weather_wind_mph                    0
# weather_humidity                  NaN
# weather_detail                   DOME

# %%
spreads = spreads[spreads['schedule_season']>=2006]
spreads = spreads[['schedule_date','schedule_season','schedule_week','team_home_abb','score_home','score_away','away_team_abb','team_favorite_id','spread_favorite','over_under_line']]
spreads['team_home_abb'] = spreads['team_home_abb'].astype(str)
spreads['team_favorite_id'] = spreads['team_favorite_id'].astype(str)
spreads['over_under_line'] = spreads['over_under_line'].astype(float)

def fav_spread(nData):
    if nData['team_home_abb'] == nData['team_favorite_id']:
        return nData['spread_favorite']
    elif nData['away_team_abb'] == nData['team_favorite_id']:
        return nData['spread_favorite']
    else:
        pass
spreads['fav_spread'] = spreads.apply(lambda nData: fav_spread(nData), axis=1)

def nonfav_spread(nData):
    if nData['team_home_abb'] != nData['team_favorite_id']:
        return nData['team_home_abb']
    elif nData['away_team_abb'] != nData['team_favorite_id']:
        return nData['away_team_abb']
    else:
        pass
spreads['team_notfav_id'] = spreads.apply(lambda nData: nonfav_spread(nData), axis=1)

def cover_or_not(nData):    
    if nData['team_home_abb'] == nData['team_favorite_id']:
        if ((nData['score_home']-nData['score_away']))+nData['spread_favorite'] > 0:
            return 'Cover'
        elif ((nData['score_home']-nData['score_away']))+nData['spread_favorite'] == 0:            
            return 'Push'       
        else:            
            return 'No Cover'
    elif nData['away_team_abb'] == nData['team_favorite_id']:        
        if ((nData['score_away']-nData['score_home']))+nData['spread_favorite'] > 0:            
            return 'Cover'        
        elif ((nData['score_away']-nData['score_home']))+nData['spread_favorite'] == 0:            
            return 'Push'        
        else:            
            return 'No Cover'
spreads['fav_cover'] = spreads.apply(lambda nData: cover_or_not(nData), axis=1)

def OU_or_not(nData):    
    if (nData['score_home']+nData['score_away']) > nData['over_under_line']:        
        return 'Over'    
    elif (nData['score_home']-nData['score_away']) == nData['over_under_line']:        
        return 'Push'    
    else:        
        return 'Under'
spreads['over_under_result'] = spreads.apply(lambda nData: OU_or_not(nData), axis=1)

##  functions to clean and scrub data by source  
def clean_spreads(df):
    ##  basic scrubbing to clean data ##    
    df['schedule_season'] = df['schedule_season'].apply(str)    
    df['schedule_week'] = df['schedule_week'].apply(str)        
    df=df.apply(lambda x: x.astype(str).str.lower())    
    #df['schedule_week']=df['schedule_week'].astype(str).str[:-2].astype(object)    
    #df['schedule_season'] = df['schedule_season'].astype(str).str[:-2].astype(object)        
    
    ##  create our unique ids  ##
    df.insert(0, "home_matchup_id", (df['team_home_abb']+'vs'+df['away_team_abb']+'_'+df['schedule_season']+'_'+df['schedule_week']))
    df.insert(1, "away_matchup_id", (df['away_team_abb']+'@'+df['team_home_abb']+'_'+df['schedule_season']+'_'+df['schedule_week']))
    df.insert(2, "home_id", (df['team_home_abb']+'_'+df['schedule_season']+'_'+df['schedule_week']))
    df.insert(3, "away_id", (df['away_team_abb']+'_'+df['schedule_season']+'_'+df['schedule_week']))
    return df
    
spreads = clean_spreads(spreads)
spreads = pd.merge(spreads, weather, on='away_matchup_id', how='left')
spreads['fav_cover'].value_counts()

sh = spreads
sa = spreads

sh = sh.rename(columns={'home_id':'team_id'})
sh.drop('away_id', axis=1, inplace=True)

sa = sa.rename(columns={'away_id':'team_id'})
sa.drop('home_id', axis=1, inplace=True)

spread_comb = pd.concat([sh, sa], axis=0)
spread_comb['team_abb'] = spread_comb['team_id'].astype(str).str[:3]
spread_comb['team_abb'] = spread_comb['team_abb'].str.replace("_","")

def hora(nData):
    if nData['team_favorite_id'] == nData['away_team_abb']:
        return 1
    else:
        return 0
spread_comb['fav_homeoraway'] = spread_comb.apply(lambda nData: hora(nData), axis=1)

## add nfl team data  ##
nfl_team = pd.read_csv(cur_dir+'/other_data/nfl_teams.txt', sep='\t')
nfl_team['team_ids'] = nfl_team['team_ids'].str.lower()
nfl_team = nfl_team[['team_ids','team_conference','team_division']]
conf_dict = dict(zip(nfl_team['team_ids'], nfl_team['team_conference']))
div_dict = dict(zip(nfl_team['team_ids'], nfl_team['team_division']))


spread_comb = pd.merge(spread_comb, nfl_team, left_on='team_abb', right_on='team_ids', how='left')
spread_comb = spread_comb[spread_comb['team_favorite_id'] != 'pick']
spread_comb = pd.merge(spread_comb, fo_roll, on='team_id', how='left')

def div_conf_game(nData, dict_type):
    abb1 = nData['team_favorite_id']
    abb2 = nData['team_notfav_id']
    for k,v in dict_type.items():
        if abb1 == k:
            v_fav = v
        elif abb2 == k:
            v_dog = v
        else:
            pass
    #print(abb1, abb2, v_fav, v_dog)
    if v_fav == v_dog:
        return 1
    else:
        return 0
#spread_comb['fav_conf_game'] = spread_comb.apply(lambda nData: div_conf_game(nData, conf_dict), axis=1)
#spread_comb['fav_div_game'] = spread_comb.apply(lambda nData: div_conf_game(nData, div_dict), axis=1)

# %%
spread_comb.tail().T
# Out:
#                                   8247             8248            8249  \
# home_matchup_id         sfvssea_2021_4  denvsbal_2021_4  gbvspit_2021_4
# away_matchup_id          sea@sf_2021_4   bal@den_2021_4   pit@gb_2021_4
# team_id                     sea_2021_4       bal_2021_4      pit_2021_4
# schedule_date                      nan              nan             nan
# schedule_season                   2021             2021            2021
# schedule_week                        4                4               4
# team_home_abb                       sf              den              gb
# score_home                         nan              nan             nan
# score_away                         nan              nan             nan
# away_team_abb                      sea              bal             pit
# team_favorite_id                    sf              den              gb
# spread_favorite                   -3.0             -1.0            -7.0
# over_under_line                   52.0             44.5            45.5
# fav_spread                        -3.0             -1.0            -7.0
# team_notfav_id                     sea              bal             pit
# fav_cover                     no cover         no cover        no cover
# over_under_result                under            under           under
# precip                               0                0               1
# dome                                 0                0               0
# temperature                         78               69              63
# wind_mph                             3                5              12
# team_abb                           sea              bal             pit
# fav_homeoraway                       0                0               0
# team_ids                           sea              bal             pit
# team_conference                    NFC              AFC             AFC
# team_division                 NFC West        AFC North       AFC North
# team                               sea              bal             pit
# w-l                                1-2              2-1             1-2
# year                              2021             2021            2021
# week                                 3                3               3
# off_dvoa_rank                        2               13              24
# off_dvoa                          32.8              4.5            -9.8
# off_weight_dvoa_rank                 2               13              24
# off_weight_dvoa                   32.8              4.5            -9.8
# pass_off_rank                        3               21              22
# pass_off                          57.4              9.6             8.3
# rush_off_rank                        2                4              29
# rush_off                            11              4.1           -32.7
# def_dvoa_rank                       24               20              18
# def_dvoa                          11.4                5             0.8
# def_weight_dvoa_rank                24               20              18
# def_weight_dvoa                   11.4                5             0.8
# pass_def_rank                       27               21              23
# pass_def                          30.8             22.1            23.6
# rush_def_rank                       18               10               6
# rush_def                         -10.2              -24           -32.3
# off_dvoa_momentum                   -4                2               2
# off_wt_dvoa_momentum                -4                4               2
# pass_off_dvoa_momentum              -3                4               1
# rush_off_dvoa_momentum              -7                1              -1
# def_dvoa_momentum                    8               11              17
# def_wt_dvoa_momentum                13                5              14
# pass_def_dvoa_momentum               7               11              22
# rush_dvoa_momentum                  11               -2               1
#
#                                  8250            8251
# home_matchup_id         nevstb_2021_4  lacvslv_2021_4
# away_matchup_id          tb@ne_2021_4   lv@lac_2021_4
# team_id                     tb_2021_4       lv_2021_4
# schedule_date                     nan             nan
# schedule_season                  2021            2021
# schedule_week                       4               4
# team_home_abb                      ne             lac
# score_home                        nan             nan
# score_away                        nan             nan
# away_team_abb                      tb              lv
# team_favorite_id                   tb             lac
# spread_favorite                  -7.0            -3.5
# over_under_line                  49.5            52.5
# fav_spread                       -7.0            -3.5
# team_notfav_id                     ne              lv
# fav_cover                    no cover        no cover
# over_under_result               under           under
# precip                              0             NaN
# dome                                0             NaN
# temperature                        60             NaN
# wind_mph                            3             NaN
# team_abb                           tb              lv
# fav_homeoraway                      1               0
# team_ids                           tb              lv
# team_conference                   NFC             AFC
# team_division               NFC South        AFC West
# team                               tb              lv
# w-l                               2-1             3-0
# year                             2021            2021
# week                                3               3
# off_dvoa_rank                       5              17
# off_dvoa                         23.8            -2.4
# off_weight_dvoa_rank                5              17
# off_weight_dvoa                  23.8            -2.4
# pass_off_rank                       6               9
# pass_off                         45.9            30.6
# rush_off_rank                       9              30
# rush_off                         -7.3             -33
# def_dvoa_rank                      17              11
# def_dvoa                          0.8            -7.4
# def_weight_dvoa_rank               17              11
# def_weight_dvoa                   0.8            -7.4
# pass_def_rank                      17              12
# pass_def                         14.4             1.1
# rush_def_rank                       7               9
# rush_def                        -31.8           -24.3
# off_dvoa_momentum                   2               3
# off_wt_dvoa_momentum                3               2
# pass_off_dvoa_momentum              1               0
# rush_off_dvoa_momentum             -1               6
# def_dvoa_momentum                  12             -17
# def_wt_dvoa_momentum               11             -17
# pass_def_dvoa_momentum             12             -14
# rush_dvoa_momentum                  6             -19

# %%
spread_for_pff = spread_comb[['home_matchup_id',
                              'schedule_season',
                              'schedule_week',
                              'team_home_abb',
                              'score_home',
                              'score_away',
                              'away_team_abb',
                              'team_favorite_id',
                              'spread_favorite',
                              'over_under_line',
                              'team_notfav_id',
                              'fav_cover',
                              'over_under_result',
                              'fav_homeoraway']]

spread_comb.tail(n=5).T
# Out:
#                                   8247             8248            8249  \
# home_matchup_id         sfvssea_2021_4  denvsbal_2021_4  gbvspit_2021_4
# away_matchup_id          sea@sf_2021_4   bal@den_2021_4   pit@gb_2021_4
# team_id                     sea_2021_4       bal_2021_4      pit_2021_4
# schedule_date                      nan              nan             nan
# schedule_season                   2021             2021            2021
# schedule_week                        4                4               4
# team_home_abb                       sf              den              gb
# score_home                         nan              nan             nan
# score_away                         nan              nan             nan
# away_team_abb                      sea              bal             pit
# team_favorite_id                    sf              den              gb
# spread_favorite                   -3.0             -1.0            -7.0
# over_under_line                   52.0             44.5            45.5
# fav_spread                        -3.0             -1.0            -7.0
# team_notfav_id                     sea              bal             pit
# fav_cover                     no cover         no cover        no cover
# over_under_result                under            under           under
# precip                               0                0               1
# dome                                 0                0               0
# temperature                         78               69              63
# wind_mph                             3                5              12
# team_abb                           sea              bal             pit
# fav_homeoraway                       0                0               0
# team_ids                           sea              bal             pit
# team_conference                    NFC              AFC             AFC
# team_division                 NFC West        AFC North       AFC North
# team                               sea              bal             pit
# w-l                                1-2              2-1             1-2
# year                              2021             2021            2021
# week                                 3                3               3
# off_dvoa_rank                        2               13              24
# off_dvoa                          32.8              4.5            -9.8
# off_weight_dvoa_rank                 2               13              24
# off_weight_dvoa                   32.8              4.5            -9.8
# pass_off_rank                        3               21              22
# pass_off                          57.4              9.6             8.3
# rush_off_rank                        2                4              29
# rush_off                            11              4.1           -32.7
# def_dvoa_rank                       24               20              18
# def_dvoa                          11.4                5             0.8
# def_weight_dvoa_rank                24               20              18
# def_weight_dvoa                   11.4                5             0.8
# pass_def_rank                       27               21              23
# pass_def                          30.8             22.1            23.6
# rush_def_rank                       18               10               6
# rush_def                         -10.2              -24           -32.3
# off_dvoa_momentum                   -4                2               2
# off_wt_dvoa_momentum                -4                4               2
# pass_off_dvoa_momentum              -3                4               1
# rush_off_dvoa_momentum              -7                1              -1
# def_dvoa_momentum                    8               11              17
# def_wt_dvoa_momentum                13                5              14
# pass_def_dvoa_momentum               7               11              22
# rush_dvoa_momentum                  11               -2               1
#
#                                  8250            8251
# home_matchup_id         nevstb_2021_4  lacvslv_2021_4
# away_matchup_id          tb@ne_2021_4   lv@lac_2021_4
# team_id                     tb_2021_4       lv_2021_4
# schedule_date                     nan             nan
# schedule_season                  2021            2021
# schedule_week                       4               4
# team_home_abb                      ne             lac
# score_home                        nan             nan
# score_away                        nan             nan
# away_team_abb                      tb              lv
# team_favorite_id                   tb             lac
# spread_favorite                  -7.0            -3.5
# over_under_line                  49.5            52.5
# fav_spread                       -7.0            -3.5
# team_notfav_id                     ne              lv
# fav_cover                    no cover        no cover
# over_under_result               under           under
# precip                              0             NaN
# dome                                0             NaN
# temperature                        60             NaN
# wind_mph                            3             NaN
# team_abb                           tb              lv
# fav_homeoraway                      1               0
# team_ids                           tb              lv
# team_conference                   NFC             AFC
# team_division               NFC South        AFC West
# team                               tb              lv
# w-l                               2-1             3-0
# year                             2021            2021
# week                                3               3
# off_dvoa_rank                       5              17
# off_dvoa                         23.8            -2.4
# off_weight_dvoa_rank                5              17
# off_weight_dvoa                  23.8            -2.4
# pass_off_rank                       6               9
# pass_off                         45.9            30.6
# rush_off_rank                       9              30
# rush_off                         -7.3             -33
# def_dvoa_rank                      17              11
# def_dvoa                          0.8            -7.4
# def_weight_dvoa_rank               17              11
# def_weight_dvoa                   0.8            -7.4
# pass_def_rank                      17              12
# pass_def                         14.4             1.1
# rush_def_rank                       7               9
# rush_def                        -31.8           -24.3
# off_dvoa_momentum                   2               3
# off_wt_dvoa_momentum                3               2
# pass_off_dvoa_momentum              1               0
# rush_off_dvoa_momentum             -1               6
# def_dvoa_momentum                  12             -17
# def_wt_dvoa_momentum               11             -17
# pass_def_dvoa_momentum             12             -14
# rush_dvoa_momentum                  6             -19

# %%
#tgs_historic = pd.read_csv(cur_dir+'/historic_data/team_game_summaries_hist.csv')
tgs_historic = pd.read_csv(cur_dir+'/historic_data/team_game_summaries_historic.csv')
#tgs_historic = pd.concat([tgs_historic, tgs_historic_old], axis=0)
tgs_2019 = pd.read_csv(cur_dir+"/current_season_data/"+cur_week_folder+'/team_game_summaries_2021_w'+cur_week+'.csv')
tgs_2019 = tgs_2019[(tgs_2019['year'] == 2021) & (tgs_2019['week'] <= int(cur_week))]

# %%
tgs_historic.tail()
# Out:
#                           team  year  week home_or_away  team_num  game_id  \
# 7659  washington-football-team  2020    13            @        32    18716
# 7660  washington-football-team  2020    14            @        32    18737
# 7661  washington-football-team  2020    15          NaN        32    18751
# 7662  washington-football-team  2020    16          NaN        32    18767
# 7663  washington-football-team  2020    17            @        32    18783
#
#                  opponent   date    time wl  ...  pass_blocking  receiving  \
# 7659  Pittsburgh Steelers  12/07  5:00pm  W  ...           53.8       62.0
# 7660  San Francisco 49ers  12/13  4:25pm  W  ...           86.0       57.7
# 7661     Seattle Seahawks  12/20  1:00pm  L  ...           83.7       61.1
# 7662    Carolina Panthers  12/27  4:05pm  L  ...           84.1       56.3
# 7663  Philadelphia Eagles  01/03  8:20pm  W  ...           75.8       57.8
#
#       rushing  run_blocking  defense  rush_defense  tackling  pass_rush  \
# 7659     42.7          57.7     75.5          81.0      55.5       68.8
# 7660     68.4          79.1     63.5          49.8      76.7       74.4
# 7661     68.1          44.1     68.2          56.0      58.3       66.7
# 7662     74.8          70.8     76.8          75.5      47.1       82.7
# 7663     65.8          64.3     64.9          70.3      69.7       62.3
#
#       coverage  special_teams
# 7659      69.9           50.5
# 7660      63.5             66
# 7661      73.5             78
# 7662      66.6           55.1
# 7663      59.0           72.7
#
# [5 rows x 25 columns]

# %%
tgs = pd.concat([tgs_historic, tgs_2019], axis=0).reset_index(drop=True)

# %%
tgs.tail()
# Out:
#                           team  year  week home_or_away  team_num  game_id  \
# 7755          tennessee-titans  2021     2            @        31    19637
# 7756          tennessee-titans  2021     3          NaN        31    19649
# 7757  washington-football-team  2021     1          NaN        32    19617
# 7758  washington-football-team  2021     2          NaN        32    19625
# 7759  washington-football-team  2021     3            @        32    19641
#
#                   opponent   date    time wl  ...  pass_blocking  receiving  \
# 7755      Seattle Seahawks  09/19  4:25pm  W  ...           65.2       63.2
# 7756    Indianapolis Colts  09/26  1:00pm  W  ...           73.2       63.9
# 7757  Los Angeles Chargers  09/12  1:00pm  L  ...           50.0       64.0
# 7758       New York Giants  09/16  8:20pm  W  ...           72.7       67.4
# 7759         Buffalo Bills  09/26  1:00pm  L  ...           92.6       58.3
#
#       rushing  run_blocking  defense  rush_defense  tackling  pass_rush  \
# 7755     82.5          56.2     64.2          68.8      55.3       61.8
# 7756     71.1          62.1     65.4          59.6      62.3       71.7
# 7757     55.6          58.9     55.2          55.7      60.0       68.3
# 7758     63.5          70.4     65.1          63.2      77.9       83.7
# 7759     62.4          54.0     68.2          71.8      84.3       77.7
#
#       coverage  special_teams
# 7755      59.0           84.5
# 7756      59.3           65.8
# 7757      49.3           53.7
# 7758      51.2             62
# 7759      53.3           61.4
#
# [5 rows x 25 columns]

# %%
tgs['team_name'] = tgs['team'].map(cleaning_dicts.clean_team_pff_full).fillna(tgs['team'])
tgs['opponent_name'] = tgs['opponent'].map(cleaning_dicts.clean_team_pff_opp).fillna(tgs['opponent'])

# %%
tgs['home_or_away']=tgs['home_or_away'].astype(str)

def home_team(nData):
    if str('@') in nData['home_or_away']:
        return nData['opponent_name']
    else:
        return nData['team_name']

tgs['home_team'] = tgs.apply(lambda nData: home_team(nData), axis=1)

def away_team(nData):
    if str('@') in nData['home_or_away']:
        return nData['team_name']
    else:
        return nData['opponent_name']
    
tgs['away_team'] = tgs.apply(lambda nData: away_team(nData), axis=1)

#tgs = pd.concat([tgs_historic, tgs_2019], axis=0).reset_index(drop=True)
#tgs = pd.read_csv('U:/Data/firefox/gov/team_game_summaries_2020.csv')
##  functions to clean and scrub data by source  ##
def clean_pff_team_summ(df):
##  basic scrubbing to clean data ##

   
    df['year'] = df['year'].astype(str)
    df['week'] = df['week'].astype(str)
    #df['home_or_away']=df['home_or_away'].str.replace('@','1')
    df['home_or_away']=np.where(df['home_or_away'] == "@", 1, 0)
    df['wl_int'] = np.where(df['wl'] == "W", 1, 0)
    df=df.replace('-','', regex=True)
    df=df.replace(' ','', regex=True)


    ##  create our unique ids  ##
    df.insert(0, "unique_team_id", (df['team_name']+'_'+df['year']+'_'+df['week']))
    df.insert(1, "team_id_impute", (df['team_name']+'_'+df['year']))
    df.insert(2, "opponent_id", (df['opponent_name']+'_'+df['year']+'_'+df['week']))
    df.insert(3, "home_matchup_id", (df['home_team']+'vs'+df['away_team']+'_'+df['year']+'_'+df['week']))
    #df.insert(4, "away_matchup_id", (df['away_team_abb']+'@'+df['team_home_abb']+'_'+df['schedule_season']+'_'+df['schedule_week']))
   

    df = df.apply(pd.to_numeric, errors='ignore')
   
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    df[num_cols]= df.groupby(df['team_id_impute'])[num_cols].fillna(df.mean()).reset_index(level=0, drop=True)
   
    return df
   
tgs_clean = clean_pff_team_summ(tgs)

tgs_clean = pd.merge(tgs_clean, spread_for_pff, on='home_matchup_id', how='left')
tgs_clean.drop_duplicates(inplace=True)
tgs_clean.head().T


def hora1(nData):
    if nData['team_favorite_id'] == nData['team_name']:
        return 1
    else:
        return 0
tgs_clean['team_favored_or_not'] = tgs_clean.apply(lambda nData: hora1(nData), axis=1)

def team_cov(nData):
    if (nData['team_favorite_id'] == nData['team_name']) & (nData['fav_cover'] == 'cover'):
        return 1
    elif (nData['team_favorite_id'] != nData['team_name']) & (nData['fav_cover'] == 'no cover'):
        return 1
    else:
        return 0
tgs_clean['ats_w'] = tgs_clean.apply(lambda nData: team_cov(nData), axis=1)

def team_no_cov(nData):
    if (nData['team_favorite_id'] == nData['team_name']) & (nData['fav_cover'] == 'no cover'):
        return 1
    elif (nData['team_favorite_id'] != nData['team_name']) & (nData['fav_cover'] == 'cover'):
        return 1
    else:
        return 0
tgs_clean['ats_l'] = tgs_clean.apply(lambda nData: team_no_cov(nData), axis=1)

# %%
tgs_clean.head(n=10).T
# Out:
#                                     0                 2                 4   \
# unique_team_id              ari_2006_1        ari_2006_2        ari_2006_3
# team_id_impute                ari_2006          ari_2006          ari_2006
# opponent_id                  sf_2006_1        sea_2006_2        lar_2006_3
# home_matchup_id         arivssf_2006_1   seavsari_2006_2   arivslar_2006_3
# team                  arizonacardinals  arizonacardinals  arizonacardinals
# year                              2006              2006              2006
# week                                 1                 2                 3
# home_or_away                         0                 1                 0
# team_num                             1                 1                 1
# game_id                           3752              3766              3784
# opponent             SanFrancisco49ers   SeattleSeahawks    LosAngelesRams
# date                             09/10             09/17             09/24
# time                            4:15pm            4:05pm            4:15pm
# wl                                   W                 L                 L
# pf                                  34                10                14
# pa                                  27                21                16
# overall_performance               72.5                48              65.6
# offense                           72.6              50.1                66
# pass                              75.5              27.9              52.6
# pass_blocking                     72.4              57.1              81.9
# receiving                         76.5              65.3              71.2
# rushing                           47.4              59.7              54.1
# run_blocking                      65.6              62.1              62.8
# defense                           67.7              49.8              62.9
# rush_defense                      69.8              38.3              80.1
# tackling                          37.5              44.7              57.1
# pass_rush                         56.2              60.5              51.7
# coverage                          70.7              62.3              53.8
# special_teams                   61.997            61.997            61.997
# team_name                          ari               ari               ari
# opponent_name                       sf               sea               lar
# home_team                          ari               sea               ari
# away_team                           sf               ari               lar
# wl_int                               1                 0                 0
# schedule_season                   2006              2006              2006
# schedule_week                        1                 2                 3
# team_home_abb                      ari               sea               ari
# score_home                        34.0              21.0              14.0
# score_away                        27.0              10.0              16.0
# away_team_abb                       sf               ari               lar
# team_favorite_id                   ari               sea               ari
# spread_favorite                   -9.5              -7.0              -5.5
# over_under_line                   44.0              48.0              45.0
# team_notfav_id                      sf               ari               lar
# fav_cover                     no cover             cover          no cover
# over_under_result                 over             under             under
# fav_homeoraway                       0                 0                 0
# team_favored_or_not                  1                 0                 1
# ats_w                                0                 0                 0
# ats_l                                1                 1                 1
#
#                                    6                 8                 10  \
# unique_team_id             ari_2006_4        ari_2006_5        ari_2006_6
# team_id_impute               ari_2006          ari_2006          ari_2006
# opponent_id                atl_2006_4         kc_2006_5        chi_2006_6
# home_matchup_id       atlvsari_2006_4    arivskc_2006_5   arivschi_2006_6
# team                 arizonacardinals  arizonacardinals  arizonacardinals
# year                             2006              2006              2006
# week                                4                 5                 6
# home_or_away                        1                 0                 0
# team_num                            1                 1                 1
# game_id                          3790              3812              3832
# opponent               AtlantaFalcons  KansasCityChiefs      ChicagoBears
# date                            10/01             10/08             10/16
# time                           1:00pm            4:05pm            8:30pm
# wl                                  L                 L                 L
# pf                                 10                20                23
# pa                                 32                23                24
# overall_performance              64.1              65.3                66
# offense                          55.5              62.9              55.4
# pass                             34.5              68.7                47
# pass_blocking                    76.9              60.2              76.7
# receiving                        68.4              59.7              65.4
# rushing                          41.9                55              34.4
# run_blocking                     61.9              65.3              62.1
# defense                            73              66.4              81.6
# rush_defense                     68.1              78.9              65.9
# tackling                         82.9                53              64.6
# pass_rush                        56.8              63.5              73.7
# coverage                         75.3              56.9              82.3
# special_teams                  61.997            61.997            61.997
# team_name                         ari               ari               ari
# opponent_name                     atl                kc               chi
# home_team                         atl               ari               ari
# away_team                         ari                kc               chi
# wl_int                              0                 0                 0
# schedule_season                  2006              2006              2006
# schedule_week                       4                 5                 6
# team_home_abb                     atl               ari               ari
# score_home                       32.0              20.0              23.0
# score_away                       10.0              23.0              24.0
# away_team_abb                     ari                kc               chi
# team_favorite_id                  atl                kc               chi
# spread_favorite                  -7.5              -3.5             -13.0
# over_under_line                  42.0              40.0              40.5
# team_notfav_id                    ari               ari               ari
# fav_cover                       cover          no cover          no cover
# over_under_result               under              over              over
# fav_homeoraway                      0                 1                 1
# team_favored_or_not                 0                 0                 0
# ats_w                               0                 1                 1
# ats_l                               1                 0                 0
#
#                                    12                14                16  \
# unique_team_id             ari_2006_7        ari_2006_8       ari_2006_10
# team_id_impute               ari_2006          ari_2006          ari_2006
# opponent_id                oak_2006_7         gb_2006_8       dal_2006_10
# home_matchup_id       oakvsari_2006_7    gbvsari_2006_8  arivsdal_2006_10
# team                 arizonacardinals  arizonacardinals  arizonacardinals
# year                             2006              2006              2006
# week                                7                 8                10
# home_or_away                        1                 1                 0
# team_num                            1                 1                 1
# game_id                          3841              3847              3886
# opponent               OaklandRaiders   GreenBayPackers     DallasCowboys
# date                            10/22             10/29             11/12
# time                           4:15pm            1:00pm            4:15pm
# wl                                  L                 L                 L
# pf                                  9                14                10
# pa                                 22                31                27
# overall_performance              60.6                55                51
# offense                          54.6              60.3              54.1
# pass                             43.6              56.9                51
# pass_blocking                    67.6              76.1              51.4
# receiving                        67.7              57.2              63.9
# rushing                          38.8              47.6              53.3
# run_blocking                     55.5              70.6              51.6
# defense                          66.5              49.5              50.5
# rush_defense                     74.4                56              48.1
# tackling                         89.2              73.1                33
# pass_rush                          56              52.5              57.8
# coverage                         60.4              45.4              51.8
# special_teams                  61.997            61.997            61.997
# team_name                         ari               ari               ari
# opponent_name                     oak                gb               dal
# home_team                         oak                gb               ari
# away_team                         ari               ari               dal
# wl_int                              0                 0                 0
# schedule_season                  2006              2006              2006
# schedule_week                       7                 8                10
# team_home_abb                     oak                gb               ari
# score_home                       22.0              31.0              10.0
# score_away                        9.0              14.0              27.0
# away_team_abb                     ari               ari               dal
# team_favorite_id                  ari                gb               dal
# spread_favorite                  -3.0              -4.0              -6.5
# over_under_line                  40.0              45.5              43.5
# team_notfav_id                    oak               ari               ari
# fav_cover                    no cover             cover             cover
# over_under_result               under             under             under
# fav_homeoraway                      1                 0                 1
# team_favored_or_not                 1                 0                 0
# ats_w                               0                 0                 0
# ats_l                               1                 1                 1
#
#                                    18
# unique_team_id            ari_2006_11
# team_id_impute               ari_2006
# opponent_id               det_2006_11
# home_matchup_id      arivsdet_2006_11
# team                 arizonacardinals
# year                             2006
# week                               11
# home_or_away                        0
# team_num                            1
# game_id                          3892
# opponent                 DetroitLions
# date                            11/19
# time                           4:05pm
# wl                                  W
# pf                                 17
# pa                                 10
# overall_performance              73.1
# offense                            76
# pass                             71.5
# pass_blocking                    78.5
# receiving                        74.6
# rushing                          71.8
# run_blocking                       59
# defense                          65.3
# rush_defense                     55.5
# tackling                         55.9
# pass_rush                        57.3
# coverage                           73
# special_teams                  61.997
# team_name                         ari
# opponent_name                     det
# home_team                         ari
# away_team                         det
# wl_int                              1
# schedule_season                  2006
# schedule_week                      11
# team_home_abb                     ari
# score_home                       17.0
# score_away                       10.0
# away_team_abb                     det
# team_favorite_id                  ari
# spread_favorite                  -2.5
# over_under_line                  45.5
# team_notfav_id                    det
# fav_cover                       cover
# over_under_result               under
# fav_homeoraway                      0
# team_favored_or_not                 1
# ats_w                               1
# ats_l                               0

# %%
tgs_cur = pd.read_csv(cur_dir+"/current_season_data/"+cur_week_folder+'/tgs_clean_pp_w'+cur_week+'.csv')

tgs_clean = pd.concat([tgs_clean, tgs_cur], axis=0)

tgs_clean = tgs_clean[['unique_team_id','team_id_impute','wl','pf','pa',
                       'opponent_id','team_name','year','week','overall_performance', 'offense', 'pass',
       'pass_blocking', 'receiving', 'rushing', 'run_blocking', 'defense',
       'rush_defense', 'tackling', 'pass_rush', 'coverage', 'special_teams',
                      'wl_int','fav_homeoraway','team_favored_or_not','ats_w','ats_l',]]

OU_ids = tgs_clean[['unique_team_id','wl','pf','opponent_id']]

tgs_clean = tgs_clean.drop(['wl'], axis=1)
tgs_clean_5 = tgs_clean.add_suffix('_overall_pff_5s')

tgs_clean= tgs_clean.add_suffix('_overall_pff')

tgs_clean.tail(n=10).T
# Out:
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                         22          23          24  \
# unique_team_id_overall_pff       no_2021_4  nyg_2021_4  nyj_2021_4
# team_id_impute_overall_pff         no_2021    nyg_2021    nyj_2021
# pf_overall_pff                          28          14           0
# pa_overall_pff                          13          17          26
# opponent_id_overall_pff          ne_2021_4  atl_2021_4  den_2021_4
# team_name_overall_pff                   no         nyg         nyj
# year_overall_pff                      2021        2021        2021
# week_overall_pff                         4           4           4
# overall_performance_overall_pff       78.3        68.4        52.4
# offense_overall_pff                   70.1        67.4        54.4
# pass_overall_pff                      50.6        71.9        53.9
# pass_blocking_overall_pff             55.7        60.4        60.1
# receiving_overall_pff                 72.6        64.1        56.1
# rushing_overall_pff                   77.7        61.1        63.7
# run_blocking_overall_pff              63.2        65.4        50.5
# defense_overall_pff                   79.9        64.5        51.4
# rush_defense_overall_pff              80.8        61.3          61
# tackling_overall_pff                    66        59.7        56.1
# pass_rush_overall_pff                 59.2        73.9        59.4
# coverage_overall_pff                  80.9        57.9        48.1
# special_teams_overall_pff             76.6        72.1        62.3
# wl_int_overall_pff                     NaN         NaN         NaN
# fav_homeoraway_overall_pff             NaN         NaN         NaN
# team_favored_or_not_overall_pff        NaN         NaN         NaN
# ats_w_overall_pff                      NaN         NaN         NaN
# ats_l_overall_pff                      NaN         NaN         NaN
#
#                                          25          26          27  \
# unique_team_id_overall_pff       phi_2021_4  pit_2021_4  sea_2021_4
# team_id_impute_overall_pff         phi_2021    pit_2021    sea_2021
# pf_overall_pff                           21          10          17
# pa_overall_pff                           41          24          30
# opponent_id_overall_pff          dal_2021_4  cin_2021_4  min_2021_4
# team_name_overall_pff                   phi         pit         sea
# year_overall_pff                       2021        2021        2021
# week_overall_pff                          4           4           4
# overall_performance_overall_pff        60.3        51.7          66
# offense_overall_pff                    66.1        52.6        69.9
# pass_overall_pff                       65.7        56.2          71
# pass_blocking_overall_pff              65.2        72.5        42.2
# receiving_overall_pff                  64.8        52.1        73.8
# rushing_overall_pff                    59.3        64.4        74.1
# run_blocking_overall_pff               61.8        43.9        51.2
# defense_overall_pff                    51.7        57.8          61
# rush_defense_overall_pff               41.3        59.8        68.3
# tackling_overall_pff                   69.2        52.6        67.7
# pass_rush_overall_pff                    66        71.9        72.8
# coverage_overall_pff                   61.8          49        45.9
# special_teams_overall_pff              66.7        57.6        56.2
# wl_int_overall_pff                      NaN         NaN         NaN
# fav_homeoraway_overall_pff              NaN         NaN         NaN
# team_favored_or_not_overall_pff         NaN         NaN         NaN
# ats_w_overall_pff                       NaN         NaN         NaN
# ats_l_overall_pff                       NaN         NaN         NaN
#
#                                         28          29          30          31
# unique_team_id_overall_pff       sf_2021_4   tb_2021_4  ten_2021_4  was_2021_4
# team_id_impute_overall_pff         sf_2021     tb_2021    ten_2021    was_2021
# pf_overall_pff                          28          24          25          21
# pa_overall_pff                          30          34          16          43
# opponent_id_overall_pff          gb_2021_4  lar_2021_4  ind_2021_4  buf_2021_4
# team_name_overall_pff                   sf          tb         ten         was
# year_overall_pff                      2021        2021        2021        2021
# week_overall_pff                         4           4           4           4
# overall_performance_overall_pff       72.8        62.3        72.2        63.7
# offense_overall_pff                   69.2        71.6        72.3          58
# pass_overall_pff                      52.4        79.6        76.6        41.1
# pass_blocking_overall_pff             70.9        60.7        73.2        92.6
# receiving_overall_pff                 68.6        70.1        63.9        58.3
# rushing_overall_pff                   68.7        58.4        71.1        62.4
# run_blocking_overall_pff              70.8        61.6        62.1          54
# defense_overall_pff                   68.2        46.6        65.4        68.2
# rush_defense_overall_pff              69.5        51.3        59.6        71.8
# tackling_overall_pff                  66.6        50.1        62.3        84.3
# pass_rush_overall_pff                 68.4        52.2        71.7        77.7
# coverage_overall_pff                    60        46.9        59.3        53.3
# special_teams_overall_pff             70.6        68.6        65.8        61.4
# wl_int_overall_pff                     NaN         NaN         NaN         NaN
# fav_homeoraway_overall_pff             NaN         NaN         NaN         NaN
# team_favored_or_not_overall_pff        NaN         NaN         NaN         NaN
# ats_w_overall_pff                      NaN         NaN         NaN         NaN
# ats_l_overall_pff                      NaN         NaN         NaN         NaN

# %%
fo.head().T
# Out:
#                                3           56          76          110  \
# team_id                 ari_2006_1  ari_2006_2  ari_2006_3  ari_2006_4
# year                          2006        2006        2006        2006
# week                             1           2           3           4
# team                           ari         ari         ari         ari
# w-l                            1-0         1-1         1-2         1-3
# off_dvoa_rank                    8          17          26          30
# off_dvoa                      19.3        -6.7       -13.6       -28.7
# off_weight_dvoa_rank             8          17          26          30
# off_weight_dvoa               19.3        -6.7       -13.6       -28.7
# pass_off_rank                    7          14          23          28
# pass_off                      57.8        16.2        -6.7       -24.1
# rush_off_rank                   23          23          20          30
# rush_off                     -21.3       -16.5        -7.6       -22.5
# def_dvoa_rank                   29          28          27          26
# def_dvoa                      23.9        15.9          14        11.2
# def_weight_dvoa_rank            29          28          27          26
# def_weight_dvoa               23.9        15.9          14        11.2
# pass_def_rank                   19          18          25          21
# pass_def                        17         2.4        18.8        12.2
# rush_def_rank                   31          32          25          27
# rush_def                      36.2          31         8.5        10.2
# off_dvoa_momentum                8          17          26          22
# off_wt_dvoa_momentum             8          17          26          22
# pass_off_dvoa_momentum           7          14          23          21
# rush_off_dvoa_momentum          23          23          20           7
# def_dvoa_momentum               29          28          27          -3
# def_wt_dvoa_momentum            29          28          27          -3
# pass_def_dvoa_momentum          19          18          25           2
# rush_dvoa_momentum              31          32          25          -4
#
#                                142
# team_id                 ari_2006_5
# year                          2006
# week                             5
# team                           ari
# w-l                            1-4
# off_dvoa_rank                   30
# off_dvoa                     -23.6
# off_weight_dvoa_rank            30
# off_weight_dvoa              -23.6
# pass_off_rank                   27
# pass_off                     -12.8
# rush_off_rank                   31
# rush_off                     -24.8
# def_dvoa_rank                   19
# def_dvoa                       3.8
# def_weight_dvoa_rank            19
# def_weight_dvoa                3.8
# pass_def_rank                   19
# pass_def                        12
# rush_def_rank                   19
# rush_def                      -5.4
# off_dvoa_momentum               13
# off_wt_dvoa_momentum            13
# pass_off_dvoa_momentum          13
# rush_off_dvoa_momentum           8
# def_dvoa_momentum               -9
# def_wt_dvoa_momentum            -9
# pass_def_dvoa_momentum           1
# rush_dvoa_momentum             -13

# %%
def rolling_tgs(data=None, roll_value=None, roll_type=None):
    
    """
        Args:
        data: input pandas dataframe to be rolled
        roll_value: input the number, default is three ## we will need to modify the function if we want more ##
        roll_type: 'mean','std', or 'var' are the only options at the point
        ## assign mean for a given team & year as opposed to the entire dataset
   
    """
    
    data = data.sort_values(by=["team_name_overall_pff","year_overall_pff","week_overall_pff"], ascending=[True, True, True])
    #data=data.fillna(data.mean())
    num_cols = data.select_dtypes(include=[np.number]).columns.tolist()
    ids = pd.DataFrame(data.select_dtypes(exclude=[np.number])).reset_index(drop=True)
   
    if roll_type == 'mean':
        #roll5 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
        #roll4 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
        roll3 = data.groupby(data['team_id_impute_overall_pff'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
        roll2 = data.groupby(data['team_id_impute_overall_pff'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-1).mean())
        roll1 = data.groupby(data['team_id_impute_overall_pff'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-2).mean())
        roll3 = pd.DataFrame(roll3.combine_first(roll2).combine_first(roll1)).reset_index(drop=True)
        df = pd.concat([ids, roll3], axis=1)
    return df
        
tgs_roll = rolling_tgs(data=tgs_clean, roll_value=3, roll_type='mean')
tgs_roll= tgs_roll[~tgs_roll['year_overall_pff'].isin(['nan'])]

# %%
def rolling_tgs_5(data=None, roll_value=None, roll_type=None):
    
    """
        Args:
        data: input pandas dataframe to be rolled
        roll_value: input the number, default is three ## we will need to modify the function if we want more ##
        roll_type: 'mean','std', or 'var' are the only options at the point
        ## assign mean for a given team & year as opposed to the entire dataset
   
    """
    
    data = data.sort_values(by=["team_name_overall_pff_5s","year_overall_pff_5s","week_overall_pff_5s"], ascending=[True, True, True])
    #data=data.fillna(data.mean())
    num_cols = data.select_dtypes(include=[np.number]).columns.tolist()
    ids = pd.DataFrame(data.select_dtypes(exclude=[np.number])).reset_index(drop=True)
   
    if roll_type == 'mean':
        roll5 = data.groupby(data['team_id_impute_overall_pff_5s'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
        roll4 = data.groupby(data['team_id_impute_overall_pff_5s'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-1).mean())
        roll3 = data.groupby(data['team_id_impute_overall_pff_5s'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-2).mean())
        roll2 = data.groupby(data['team_id_impute_overall_pff_5s'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-3).mean())
        roll1 = data.groupby(data['team_id_impute_overall_pff_5s'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-4).mean())
        roll5 = pd.DataFrame(roll5.combine_first(roll4).combine_first(roll3).combine_first(roll2).combine_first(roll1)).reset_index(drop=True)
        df = pd.concat([ids, roll5], axis=1)
    return df
        
tgs_roll_5 = rolling_tgs_5(data=tgs_clean_5, roll_value=5, roll_type='mean')
tgs_roll_5= tgs_roll_5[~tgs_roll_5['year_overall_pff_5s'].isin(['nan'])]

# %%
tgs_roll_5.rename(columns={'unique_team_id_overall_pff_5s':'unique_team_id_overall_pff'}, inplace=True)
tgs_roll_5 = tgs_roll_5[['unique_team_id_overall_pff',
       'pf_overall_pff_5s', 'pa_overall_pff_5s', 'overall_performance_overall_pff_5s',
       'offense_overall_pff_5s', 'pass_overall_pff_5s', 'pass_blocking_overall_pff_5s',
       'receiving_overall_pff_5s', 'rushing_overall_pff_5s',
       'run_blocking_overall_pff_5s', 'defense_overall_pff_5s',
       'rush_defense_overall_pff_5s', 'tackling_overall_pff_5s',
       'pass_rush_overall_pff_5s', 'coverage_overall_pff_5s',
       'special_teams_overall_pff_5s', 'wl_int_overall_pff_5s',
       'fav_homeoraway_overall_pff_5s', 'team_favored_or_not_overall_pff_5s',
       'ats_w_overall_pff_5s', 'ats_l_overall_pff_5s']]

# %%
tgs_roll = pd.merge(tgs_roll, tgs_roll_5, on='unique_team_id_overall_pff', how='left')

# %%
tgs_roll.drop(['year_overall_pff', 'week_overall_pff', 
                'team_id_impute_overall_pff','team_name_overall_pff'], axis=1, inplace=True)
tgs_roll.rename(columns={'unique_team_id_overall_pff':'unique_team_id'}, inplace=True)
tgs_roll = pd.merge(OU_ids, tgs_roll, on='unique_team_id', how='left')

# %%
tgs_roll.columns
# Out:
# Index(['unique_team_id', 'wl', 'pf', 'opponent_id', 'opponent_id_overall_pff',
#        'pf_overall_pff', 'pa_overall_pff', 'overall_performance_overall_pff',
#        'offense_overall_pff', 'pass_overall_pff', 'pass_blocking_overall_pff',
#        'receiving_overall_pff', 'rushing_overall_pff',
#        'run_blocking_overall_pff', 'defense_overall_pff',
#        'rush_defense_overall_pff', 'tackling_overall_pff',
#        'pass_rush_overall_pff', 'coverage_overall_pff',
#        'special_teams_overall_pff', 'wl_int_overall_pff',
#        'fav_homeoraway_overall_pff', 'team_favored_or_not_overall_pff',
#        'ats_w_overall_pff', 'ats_l_overall_pff', 'pf_overall_pff_5s',
#        'pa_overall_pff_5s', 'overall_performance_overall_pff_5s',
#        'offense_overall_pff_5s', 'pass_overall_pff_5s',
#        'pass_blocking_overall_pff_5s', 'receiving_overall_pff_5s',
#        'rushing_overall_pff_5s', 'run_blocking_overall_pff_5s',
#        'defense_overall_pff_5s', 'rush_defense_overall_pff_5s',
#        'tackling_overall_pff_5s', 'pass_rush_overall_pff_5s',
#        'coverage_overall_pff_5s', 'special_teams_overall_pff_5s',
#        'wl_int_overall_pff_5s', 'fav_homeoraway_overall_pff_5s',
#        'team_favored_or_not_overall_pff_5s', 'ats_w_overall_pff_5s',
#        'ats_l_overall_pff_5s'],
#       dtype='object')

# %%
rush_std.head().T
# Out:
#                                      0                    1              2  \
# player                  Chester Taylor  LaDainian Tomlinson  Willie Parker
# position                            HB                   HB             HB
# team_name                          MIN                   SD            PIT
# player_game_count                    1                    1              1
# attempts                            31                   31             29
# avoided_tackles                      4                    1              4
# breakaway_attempts                   0                    1              1
# breakaway_percent                    0                 44.3           27.8
# breakaway_yards                      0                   58             32
# declined_penalties                   0                    0              0
# designed_yards                      87                  131            115
# drops                                0                    0              0
# elu_recv_mtf                         0                    0              2
# elu_rush_mtf                         4                    1              4
# elu_yco                             61                  100             95
# elusive_rating                    23.1                  9.5           61.4
# explosive                            1                    2              2
# first_downs                          4                    5              4
# franchise_id                        18                   27             25
# fumbles                              0                    0              0
# gap_attempts                         5                   17             23
# grades_offense                    54.9                 50.3           71.6
# grades_offense_penalty            74.6                 73.2           73.3
# grades_pass                        NaN                  NaN            NaN
# grades_pass_block                 82.3                 77.9           48.9
# grades_pass_route                 57.3                 76.1           79.9
# grades_run                        54.4                   49           68.7
# grades_run_block                    60                   60             60
# longest                             10                   58             32
# penalties                            0                    0              0
# rec_yards                           43                   18             13
# receptions                           3                    3              3
# routes                              12                    7             11
# run_plays                           33                   35             30
# scramble_yards                       0                    0              0
# scrambles                            0                    0              0
# targets                              3                    3              4
# total_touches                       34                   34             32
# touchdowns                           1                    1              0
# yards                               87                  131            115
# yards_after_contact                 61                  100             95
# yco_attempt                       1.97                 3.23           3.28
# ypa                                2.8                  4.2              4
# yprr                              3.58                 2.57           1.18
# zone_attempts                       26                   12              6
# week                                 1                    1              1
# year                              2006                 2006           2006
#
#                                    3             4
# player                  Warrick Dunn  Rudi Johnson
# position                          HB            HB
# team_name                        ATL           CIN
# player_game_count                  1             1
# attempts                          29            28
# avoided_tackles                    2             2
# breakaway_attempts                 3             2
# breakaway_percent               48.5          39.6
# breakaway_yards                   64            38
# declined_penalties                 0             0
# designed_yards                   132            96
# drops                              0             0
# elu_recv_mtf                       0             0
# elu_rush_mtf                       2             2
# elu_yco                           58            62
# elusive_rating                  13.3          15.3
# explosive                          4             2
# first_downs                        7             5
# franchise_id                       2             7
# fumbles                            0             0
# gap_attempts                       2            14
# grades_offense                    57          50.8
# grades_offense_penalty          73.9          73.9
# grades_pass                      NaN           NaN
# grades_pass_block               22.4          75.1
# grades_pass_route               65.9          58.3
# grades_run                        59          51.5
# grades_run_block                59.1          59.8
# longest                           25            22
# penalties                          0             0
# rec_yards                         10             7
# receptions                         1             1
# routes                            11             8
# run_plays                         34            33
# scramble_yards                     0             0
# scrambles                          0             0
# targets                            1             1
# total_touches                     30            29
# touchdowns                         0             1
# yards                            132            96
# yards_after_contact               58            62
# yco_attempt                        2          2.21
# ypa                              4.6           3.4
# yprr                            0.91          0.88
# zone_attempts                     25            10
# week                               1             1
# year                            2006          2006

# %% [markdown]
# ### Clean and Subset PFF Data into Positional Groupings

# %%
##  clean the player name field from pfr function above
qb_standard['player'] = qb_standard.apply(lambda df: clean_name(df), axis=1)
oline['player'] = oline.apply(lambda df: clean_name(df), axis=1)
rush_std['player'] = rush_std.apply(lambda df: clean_name(df), axis=1)
rec_std['player'] = rec_std.apply(lambda df: clean_name(df), axis=1)
def_standard['player'] = def_standard.apply(lambda df: clean_name(df), axis=1)


##  functions to clean and scrub data by source  ##
def clean_pff(df):
##  basic scrubbing to clean data ##
    df['position']=df['position'].astype(str).str.lower()
    df['team_name']=df['team_name'].astype(str).str.lower()
    df['year'] = df['year'].astype(str)
    df['week'] = df['week'].astype(str)
    df=df.replace('-','', regex=True)
    df=df.replace(' ','', regex=True)

   
    ##  pass team name through dictionary to clean ##
    df['team_name'] = df['team_name'].map(cleaning_dicts.clean_team_pff).fillna(df['team_name'])
    df['position'] = df['position'].map(cleaning_dicts.pos_dict).fillna(df['position'])

   
    ##  create our unique ids  ##
    df.insert(0, "unique_id", (df['player']+'_'+df['team_name']+'_'+df['year']+'_'+df['week']))
    df.insert(1, "player_id", (df['player']+'_'+df['team_name']+'_'+df['year']))
    df.insert(2, "unique_team_id", (df['team_name']+'_'+df['year']+'_'+df['week']))
    df.insert(3, "team_id_impute", (df['team_name']+'_'+df['year']))
    df.insert(4, "player_name", (df['player']))
    df.insert(5, "player_team", (df['player']+'_'+df['team_name']))   
#    df['year'] = df['year'].astype(int)
#    df['week'] = df['week'].astype(int)
    df = df.apply(pd.to_numeric, errors='ignore')
   
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    df[num_cols]= df.groupby(df['team_id_impute'])[num_cols].fillna(df.mean()).reset_index(level=0, drop=True)
    #df = df.groupby('year').transform(lambda x: (x - x.mean()) / x.std())
    
    return df



rush_std = clean_pff(rush_std)
qb_standard =clean_pff(qb_standard)
oline=clean_pff(oline)
rec_std=clean_pff(rec_std)
def_standard=clean_pff(def_standard)

# %%
qb_standard.tail().T
# Out:
#                                           9282                     9283  \
# unique_id              jameiswinston_no_2021_3  justinfields_chi_2021_3
# player_id                jameiswinston_no_2021    justinfields_chi_2021
# unique_team_id                       no_2021_3               chi_2021_3
# team_id_impute                         no_2021                 chi_2021
# player_name                      jameiswinston             justinfields
# player_team                   jameiswinston_no         justinfields_chi
# player                           jameiswinston             justinfields
# position                                    qb                       qb
# team_name                                   no                      chi
# player_game_count                            1                        1
# accuracy_percent                          68.4                     33.3
# aimed_passes                                19                       18
# attempts                                    21                       20
# avg_depth_of_target                       11.3                      6.2
# avg_time_to_throw                         3.68                     2.84
# bats                                         0                        0
# big_time_throws                              0                        0
# btt_rate                                     0                        0
# completion_percent                        61.9                       30
# completions                                 13                        6
# declined_penalties                           0                        0
# def_gen_pressures                           11                       16
# drop_rate                                    0                        0
# dropbacks                                   26                       30
# drops                                        0                        0
# first_downs                                  9                        2
# franchise_id                                20                        6
# grades_hands_fumble                       77.4                     78.4
# grades_offense                            51.1                     46.8
# grades_pass                               50.6                     49.3
# grades_run                                57.3                     51.2
# hit_as_threw                                 1                        1
# interceptions                                0                        0
# passing_snaps                               26                       33
# penalties                                    0                        0
# pressure_to_sack_rate                     27.3                     56.3
# qb_rating                                110.8                     41.3
# sack_percent                              11.5                       30
# sacks                                        3                        9
# scrambles                                    2                        1
# spikes                                       0                        0
# thrown_aways                                 1                        1
# touchdowns                                   2                        0
# turnover_worthy_plays                        1                        0
# twp_rate                                   3.8                        0
# yards                                      128                       68
# ypa                                        6.1                      3.4
# week                                         3                        3
# year                                      2021                     2021
#
#                                        9284                    9285  \
# unique_id              joeburrow_cin_2021_3  dandreswift_det_2021_3
# player_id                joeburrow_cin_2021    dandreswift_det_2021
# unique_team_id                   cin_2021_3              det_2021_3
# team_id_impute                     cin_2021                det_2021
# player_name                       joeburrow             dandreswift
# player_team                   joeburrow_cin         dandreswift_det
# player                            joeburrow             dandreswift
# position                                 qb                      hb
# team_name                               cin                     det
# player_game_count                         1                       1
# accuracy_percent                       83.3                  71.571
# aimed_passes                             18                       0
# attempts                                 18                       1
# avg_depth_of_target                     8.8                 9.10848
# avg_time_to_throw                      2.42                     2.4
# bats                                      0                       0
# big_time_throws                           2                       0
# btt_rate                                 10                       0
# completion_percent                     77.8                       0
# completions                              14                       0
# declined_penalties                        0                       0
# def_gen_pressures                         3                       1
# drop_rate                               6.7                 8.37244
# dropbacks                                19                       1
# drops                                     1                       0
# first_downs                               7                       0
# franchise_id                              7                      11
# grades_hands_fumble                    76.9                      77
# grades_offense                         90.3                    82.1
# grades_pass                            89.6                      60
# grades_run                             66.3                    66.9
# hit_as_threw                              0                       1
# interceptions                             1                       0
# passing_snaps                            22                       1
# penalties                                 0                       0
# pressure_to_sack_rate                     0                       0
# qb_rating                             122.9                    39.6
# sack_percent                              0                       0
# sacks                                     0                       0
# scrambles                                 1                       0
# spikes                                    0                       0
# thrown_aways                              0                       0
# touchdowns                                3                       0
# turnover_worthy_plays                     1                       0
# twp_rate                                4.5                       0
# yards                                   172                       0
# ypa                                     9.6                       0
# week                                      3                       3
# year                                   2021                    2021
#
#                                               9286
# unique_id              mitchelltrubisky_buf_2021_3
# player_id                mitchelltrubisky_buf_2021
# unique_team_id                          buf_2021_3
# team_id_impute                            buf_2021
# player_name                       mitchelltrubisky
# player_team                   mitchelltrubisky_buf
# player                            mitchelltrubisky
# position                                        qb
# team_name                                      buf
# player_game_count                                1
# accuracy_percent                               100
# aimed_passes                                     1
# attempts                                         1
# avg_depth_of_target                              0
# avg_time_to_throw                              3.1
# bats                                             0
# big_time_throws                                  0
# btt_rate                                         0
# completion_percent                             100
# completions                                      1
# declined_penalties                               0
# def_gen_pressures                                1
# drop_rate                                        0
# dropbacks                                        2
# drops                                            0
# first_downs                                      1
# franchise_id                                     4
# grades_hands_fumble                           69.1
# grades_offense                                73.7
# grades_pass                                     60
# grades_run                                    69.5
# hit_as_threw                                     0
# interceptions                                    0
# passing_snaps                                    2
# penalties                                        0
# pressure_to_sack_rate                            0
# qb_rating                                     79.2
# sack_percent                                     0
# sacks                                            0
# scrambles                                        1
# spikes                                           0
# thrown_aways                                     0
# touchdowns                                       0
# turnover_worthy_plays                            0
# twp_rate                                         0
# yards                                            1
# ypa                                              1
# week                                             3
# year                                          2021

# %%
spread_comb.columns
# Out:
# Index(['home_matchup_id', 'away_matchup_id', 'team_id', 'schedule_date',
#        'schedule_season', 'schedule_week', 'team_home_abb', 'score_home',
#        'score_away', 'away_team_abb', 'team_favorite_id', 'spread_favorite',
#        'over_under_line', 'fav_spread', 'team_notfav_id', 'fav_cover',
#        'over_under_result', 'precip', 'dome', 'temperature', 'wind_mph',
#        'team_abb', 'fav_homeoraway', 'team_ids', 'team_conference',
#        'team_division', 'team', 'w-l', 'year', 'week', 'off_dvoa_rank',
#        'off_dvoa', 'off_weight_dvoa_rank', 'off_weight_dvoa', 'pass_off_rank',
#        'pass_off', 'rush_off_rank', 'rush_off', 'def_dvoa_rank', 'def_dvoa',
#        'def_weight_dvoa_rank', 'def_weight_dvoa', 'pass_def_rank', 'pass_def',
#        'rush_def_rank', 'rush_def', 'off_dvoa_momentum',
#        'off_wt_dvoa_momentum', 'pass_off_dvoa_momentum',
#        'rush_off_dvoa_momentum', 'def_dvoa_momentum', 'def_wt_dvoa_momentum',
#        'pass_def_dvoa_momentum', 'rush_dvoa_momentum'],
#       dtype='object')

# %%
spread_comb2 = spread_comb[['home_matchup_id', 'away_matchup_id', 'team_id', 'schedule_season', 'schedule_week', 'team_home_abb', 'score_home',
       'score_away', 'away_team_abb', 'team_favorite_id', 'spread_favorite',
       'over_under_line', 'fav_spread', 'team_notfav_id',]]

# %%
fo.head().T
# Out:
#                                3           56          76          110  \
# team_id                 ari_2006_1  ari_2006_2  ari_2006_3  ari_2006_4
# year                          2006        2006        2006        2006
# week                             1           2           3           4
# team                           ari         ari         ari         ari
# w-l                            1-0         1-1         1-2         1-3
# off_dvoa_rank                    8          17          26          30
# off_dvoa                      19.3        -6.7       -13.6       -28.7
# off_weight_dvoa_rank             8          17          26          30
# off_weight_dvoa               19.3        -6.7       -13.6       -28.7
# pass_off_rank                    7          14          23          28
# pass_off                      57.8        16.2        -6.7       -24.1
# rush_off_rank                   23          23          20          30
# rush_off                     -21.3       -16.5        -7.6       -22.5
# def_dvoa_rank                   29          28          27          26
# def_dvoa                      23.9        15.9          14        11.2
# def_weight_dvoa_rank            29          28          27          26
# def_weight_dvoa               23.9        15.9          14        11.2
# pass_def_rank                   19          18          25          21
# pass_def                        17         2.4        18.8        12.2
# rush_def_rank                   31          32          25          27
# rush_def                      36.2          31         8.5        10.2
# off_dvoa_momentum                8          17          26          22
# off_wt_dvoa_momentum             8          17          26          22
# pass_off_dvoa_momentum           7          14          23          21
# rush_off_dvoa_momentum          23          23          20           7
# def_dvoa_momentum               29          28          27          -3
# def_wt_dvoa_momentum            29          28          27          -3
# pass_def_dvoa_momentum          19          18          25           2
# rush_dvoa_momentum              31          32          25          -4
#
#                                142
# team_id                 ari_2006_5
# year                          2006
# week                             5
# team                           ari
# w-l                            1-4
# off_dvoa_rank                   30
# off_dvoa                     -23.6
# off_weight_dvoa_rank            30
# off_weight_dvoa              -23.6
# pass_off_rank                   27
# pass_off                     -12.8
# rush_off_rank                   31
# rush_off                     -24.8
# def_dvoa_rank                   19
# def_dvoa                       3.8
# def_weight_dvoa_rank            19
# def_weight_dvoa                3.8
# pass_def_rank                   19
# pass_def                        12
# rush_def_rank                   19
# rush_def                      -5.4
# off_dvoa_momentum               13
# off_wt_dvoa_momentum            13
# pass_off_dvoa_momentum          13
# rush_off_dvoa_momentum           8
# def_dvoa_momentum               -9
# def_wt_dvoa_momentum            -9
# pass_def_dvoa_momentum           1
# rush_dvoa_momentum             -13

# %% [markdown]
# import numpy as np
# import pandas as pd
#
# #fo = pd.read_csv('U:\\Data\\firefox\\gov\\fo_final.csv', error_bad_lines=True)
# #qb = pd.read_csv('//ain2/dfsroot/userdata21/thomapb4/Data/Desktop Backup/FP.txt', sep=',', error_bad_lines=True)
# qb = qb_standard
# match=spread_comb2
#
# #match = pd.read_csv('U:\\Data\\firefox\\gov\\predssub.csv', error_bad_lines=True)
# match['isin_team_id'] = match.apply(lambda x: x.team_favorite_id in x.team_id, axis=1)
#
# def hora(nData):
#     if nData['isin_team_id'] == True:
#         return nData['team_notfav_id']
#     else:
#         return nData['team_favorite_id']
#
# match['opp_abb'] = match.apply(lambda nData: hora(nData), axis=1)
#
#
# match['isin_team_id'] = match.apply(lambda x: x.team_home_abb in x.team_id, axis=1)
#
# def scora(nData):
#     if nData['isin_team_id'] == True:
#         return nData['score_home']
#     else:
#         return nData['score_away']
#
# match['score'] = match.apply(lambda nData: scora(nData), axis=1)
#
#
# match['schedule_season']=match['schedule_season'].apply(str)
# match['schedule_week']=match['schedule_week'].apply(str)
# match['opp_id']= match.opp_abb.str.cat(match.schedule_season, sep="_").str.cat(match.schedule_week, sep="_")
# match = match[['team_id','opp_id','score']]
#
# qb = pd.merge(qb, match, left_on='team_id_impute', right_on='team_id', how='left').merge(fo, left_on='opp_id', right_on='team_id', how='left')
#
# #m = pd.merge(qb, fo, on='team_id', how='left')
# m = qb[['unique_id','player_team','team_id_x','player','year_x','week_x','score','pass_pff_off','pass_pff_pass', 'passes_underpressure', 'pass_time_to_throw','pass_adj_comp_perc','nfl_passer_rating','def_dvoa_rank','pass_def_rank']]
# m['tough_matchup'] = np.where(m['def_dvoa_rank'] <= 15, 'tough', 'easy')
#
#
# conditions = [m['def_dvoa_rank'] <= 10, m['def_dvoa_rank'] >= 21]
# choices = ['hard', 'easy']
#
# m['tough_matchup'] = np.select(conditions, choices)
# m['tough_matchup'] = m['tough_matchup'].str.replace('0','mid')
# grp = m.groupby(['player','tough_matchup']).mean().reset_index()
# grp2 = m.groupby(['player','tough_matchup']).agg({'unique_id':'count'}).reset_index()
# grp2.drop(['player','tough_matchup'], axis=1, inplace=True)
# grp2.columns = ['game_exp']
# grp = pd.concat([grp, grp2], axis=1)
#
# inexp = grp[(grp['game_exp'] <= 5)]
# inexp = inexp.groupby(['tough_matchup']).mean().reset_index()
#
# ls = []
# for yr in range(2007, 2021, 1):
#     for wk in range(1, 18, 1):
#         print(yr, wk)
#         temp = m[(m['year_x'] <= int(yr)) & (m['year_x'] >= int(yr) - 5)]
#         trash = temp[(temp['year_x'] == int(yr)) & (temp['week_x'] >= int(wk))]
#         temp=temp[~temp.index.isin(trash.index)]
#         temp.drop_duplicates(subset=['player','year_x','week_x'], keep='first', inplace=True)
#
#         conditions = [temp['def_dvoa_rank'] <= 10, temp['def_dvoa_rank'] >= 21]
#         choices = ['hard', 'easy']
#
#         temp['tough_matchup'] = np.select(conditions, choices)
#         temp['tough_matchup'] = temp['tough_matchup'].str.replace('0','mid')
#         grp = temp.groupby(['player','tough_matchup']).mean().reset_index()
#         grp2 = temp.groupby(['player','tough_matchup']).agg({'unique_id':'count'}).reset_index()
#         grp2.drop(['player','tough_matchup'], axis=1, inplace=True)
#         grp2.columns = ['game_exp']
#         grp = pd.concat([grp, grp2], axis=1)
#         grp['year_x'] = str(yr)
#         grp['week_x'] = str(wk)
#         #grp['player_grp_id']= grp['player'].str.cat(str(yr), sep="_").str.cat(str(wk), sep="_")
#         ls.append(grp)
#
# matchups = pd.concat(ls)
# matchups['unique__id']= matchups.player.str.cat(matchups.year_x, sep="_").str.cat(matchups.week_x, sep="_")

# %% [markdown]
# ### Create copies after the groupby imputes b/c it take time

# %%
rush_std_copy = rush_std
qb_standard_copy= qb_standard
oline_copy=oline
rec_std_copy=rec_std
def_standard_copy=def_standard

rush_std = rush_std_copy
qb_standard = qb_standard_copy
oline=oline_copy
rec_std=rec_std_copy
def_standard=def_standard_copy

# %%
rush_std = rush_std_copy
qb_standard = qb_standard_copy
oline=oline_copy
rec_std=rec_std_copy
def_standard=def_standard_copy

# %%
#This cell is foor exporting the player pool to for spot testing purposes#
#rush_std_new.to_csv(cur_dir+'/other_data/rush_std_new_pp.csv')
#qb_standard_new.to_csv(cur_dir+'/other_data/qb_standard_conc.csv')
#oline_standard_new.to_csv(cur_dir+'/other_data/oline_standard_new_pp.csv')
#rec_std_new.to_csv(cur_dir+'/other_data/rec_std_new_pp.csv')
#def_standard_new.to_csv(cur_dir+'/other_data/def_standard_new_pp.csv')

# %% [markdown]
# Combine injury data onto clean pff datasets for current week

# %%
rush_std_new = pd.read_csv(cur_dir+"/current_season_data/"+cur_week_folder+'/rush_std_new_pp_w'+cur_week+'.csv')
qb_standard_new = pd.read_csv(cur_dir+"/current_season_data/"+cur_week_folder+'/qb_standard_new_pp_w'+cur_week+'.csv')
oline_standard_new = pd.read_csv(cur_dir+"/current_season_data/"+cur_week_folder+'/oline_standard_new_pp_w'+cur_week+'.csv')
rec_std_new = pd.read_csv(cur_dir+"/current_season_data/"+cur_week_folder+'/rec_std_new_pp_w'+cur_week+'.csv')
def_standard_new = pd.read_csv(cur_dir+"/current_season_data/"+cur_week_folder+'/def_standard_new_pp_w'+cur_week+'.csv')

rush_std_new['week'] = rush_std_new['plyr_number']
qb_standard_new['week'] = qb_standard_new['plyr_number']
oline_standard_new['week'] = oline_standard_new['plyr_number']
rec_std_new['week'] = rec_std_new['plyr_number']
def_standard_new['week'] = def_standard_new['plyr_number']

# %%
qb_standard_new.drop('plyr_number', axis=1, inplace=True)
oline_standard_new.drop('plyr_number', axis=1, inplace=True)
rush_std_new.drop('plyr_number', axis=1, inplace=True)
rec_std_new.drop('plyr_number', axis=1, inplace=True)
def_standard_new.drop('plyr_number', axis=1, inplace=True)

# %%
qb_standard = pd.concat([qb_standard, qb_standard_new], axis=0)
oline = pd.concat([oline, oline_standard_new], axis=0)
#qb_adj = pd.concat([qb_adj, qb_adj_2019, qb_adj_nw], axis=0)
rush_std = pd.concat([rush_std, rush_std_new], axis=0)
rec_std = pd.concat([rec_std, rec_std_new], axis=0)
def_standard = pd.concat([def_standard, def_standard_new], axis=0)

#qb_adj = qb_adj[['unique_id','qb_adjform','adj_perc']]
#qb_standard = pd.merge(qb_standard, qb_adj, on='unique_id', how='left')


rush_std=rush_std.apply(pd.to_numeric, errors='ignore')
def_rbs = rush_std[rush_std['position'].isin(['hb','fb','qb'])]

qb_standard=qb_standard.apply(pd.to_numeric, errors='ignore')
def_qbs = qb_standard[qb_standard['position'].isin(['qb'])]

rec_std=rec_std.apply(pd.to_numeric, errors='ignore')
def_rec = rec_std[rec_std['position'].isin(['wr','te','hb'])]

#oline['position']=oline['oline_starter']
oline=oline.apply(pd.to_numeric, errors='ignore')
def_oline = oline[oline['position'].isin(['t','g','ol','c'])]

defense=def_standard.apply(pd.to_numeric, errors='ignore')

# %%
def_oline.position.value_counts()
# Out:
# t     19124
# g     18702
# ol     8689
# Name: position, dtype: int64

# %% [markdown]
# ### Roll Data Function

# %%
def rolling(data=None, roll_value=None, roll_type=None):
    
    """
        Args:
        data: input pandas dataframe to be rolled
        roll_value: input the number, default is three ## we will need to modify the function if we want more ##
        roll_type: 'mean','std', or 'var' are the only options at the point
        ## assign mean for a given team & year as opposed to the entire dataset
   
    """
    
    data = data.sort_values(by=["player","team_name","year","week"], ascending=[True, True, True, True])
    #data=data.fillna(data.mean())
    num_cols = data.select_dtypes(include=[np.number]).columns.tolist()
    ids = pd.DataFrame(data.select_dtypes(exclude=[np.number])).reset_index(drop=True)
   
    if roll_type == 'mean':
        #roll5 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
        #roll4 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
        roll3 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).mean())
        roll2 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-1).mean())
        roll1 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-2).mean())
        roll3 = pd.DataFrame(roll3.combine_first(roll2).combine_first(roll1)).reset_index(drop=True)
        df = pd.concat([ids, roll3], axis=1)
    elif roll_type == 'std':
        roll5 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).std())
        roll4 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-1).std())
        roll3 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-2).std())
        roll2 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-3).std())
        roll1 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-4).std())
        roll3 = pd.DataFrame(roll3.combine_first(roll2).combine_first(roll1)).reset_index(drop=True)
        df = pd.concat([ids, roll3], axis=1)
    elif roll_type == 'var':
        roll3 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value).var())
        roll2 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-1).var())
        roll1 = data.groupby(data['player_id'])[num_cols].apply(lambda x : x.shift().rolling(roll_value-2).var())
        roll3 = pd.DataFrame(roll3.combine_first(roll2).combine_first(roll1)).reset_index(drop=True)
        df = pd.concat([ids, roll3], axis=1)
    return df
   
roll_rbs = rolling(data=def_rbs, roll_value=3, roll_type='mean')
roll_qbs = rolling(data=def_qbs, roll_value=3, roll_type='mean')
roll_wr_recs = rolling(data= def_rec, roll_value=3, roll_type='mean')
roll_oline = rolling(data=def_oline, roll_value=3, roll_type='mean')
roll_defense = rolling(data=defense, roll_value=3, roll_type='mean')

# %%
rbs=roll_rbs
qbs=roll_qbs
wrs=roll_wr_recs
ol=roll_oline
defense=roll_defense

# %%
roll_rbs=rbs
roll_qbs=qbs
roll_wr_recs=wrs
roll_oline=ol
roll_defense=defense

# %%
roll_rbs.to_csv(cur_dir+'/other_data/roll_rbs.csv')

# %%
num_cols = def_rbs.select_dtypes(include=[np.number]).columns.tolist()
print(num_cols)
# Out:
# ['player_game_count', 'attempts', 'avoided_tackles', 'breakaway_attempts', 'breakaway_percent', 'breakaway_yards', 'declined_penalties', 'designed_yards', 'drops', 'elu_recv_mtf', 'elu_rush_mtf', 'elu_yco', 'elusive_rating', 'explosive', 'first_downs', 'franchise_id', 'fumbles', 'gap_attempts', 'grades_offense', 'grades_offense_penalty', 'grades_pass', 'grades_pass_block', 'grades_pass_route', 'grades_run', 'grades_run_block', 'longest', 'penalties', 'rec_yards', 'receptions', 'routes', 'run_plays', 'scramble_yards', 'scrambles', 'targets', 'total_touches', 'touchdowns', 'yards', 'yards_after_contact', 'yco_attempt', 'ypa', 'yprr', 'zone_attempts', 'week', 'year']

# %%
def_oline.T
# Out:
#                                                     0    \
# unique_id                        peneisewell_det_2006_1
# player_id                          peneisewell_det_2006
# unique_team_id                               det_2006_1
# team_id_impute                                 det_2006
# player_name                                 peneisewell
# player_team                             peneisewell_det
# player                                      peneisewell
# position                                              t
# team_name                                           det
# player_game_count                                     1
# block_percent                                       100
# declined_penalties                                    0
# franchise_id                                         11
# grades_offense                                     75.6
# grades_pass_block                                  67.5
# grades_run_block                                   78.8
# hits_allowed                                          2
# hurries_allowed                                       4
# non_spike_pass_block                                 63
# non_spike_pass_block_percentage                     100
# pass_block_percent                                  100
# pbe                                                95.2
# penalties                                             0
# pressures_allowed                                     6
# sacks_allowed                                         0
# snap_counts_block                                    92
# snap_counts_ce                                        0
# snap_counts_lg                                        0
# snap_counts_lt                                       91
# snap_counts_offense                                  92
# snap_counts_pass_block                               71
# snap_counts_pass_play                                71
# snap_counts_rg                                        0
# snap_counts_rt                                        0
# snap_counts_run_block                                21
# snap_counts_te                                        1
# week                                                  1
# year                                               2006
#
#                                                              1    \
# unique_id                        halapoulivaativaitai_det_2006_1
# player_id                          halapoulivaativaitai_det_2006
# unique_team_id                                        det_2006_1
# team_id_impute                                          det_2006
# player_name                                 halapoulivaativaitai
# player_team                             halapoulivaativaitai_det
# player                                      halapoulivaativaitai
# position                                                       g
# team_name                                                    det
# player_game_count                                              1
# block_percent                                                100
# declined_penalties                                             0
# franchise_id                                                  11
# grades_offense                                              54.3
# grades_pass_block                                           49.5
# grades_run_block                                            54.5
# hits_allowed                                                   0
# hurries_allowed                                                5
# non_spike_pass_block                                          63
# non_spike_pass_block_percentage                              100
# pass_block_percent                                           100
# pbe                                                           96
# penalties                                                      0
# pressures_allowed                                              5
# sacks_allowed                                                  0
# snap_counts_block                                             92
# snap_counts_ce                                                 0
# snap_counts_lg                                                 0
# snap_counts_lt                                                 0
# snap_counts_offense                                           92
# snap_counts_pass_block                                        71
# snap_counts_pass_play                                         71
# snap_counts_rg                                                92
# snap_counts_rt                                                 0
# snap_counts_run_block                                         21
# snap_counts_te                                                 0
# week                                                           1
# year                                                        2006
#
#                                                     2    \
# unique_id                        frankragnow_det_2006_1
# player_id                          frankragnow_det_2006
# unique_team_id                               det_2006_1
# team_id_impute                                 det_2006
# player_name                                 frankragnow
# player_team                             frankragnow_det
# player                                      frankragnow
# position                                             ol
# team_name                                           det
# player_game_count                                     1
# block_percent                                       100
# declined_penalties                                    0
# franchise_id                                         11
# grades_offense                                     83.7
# grades_pass_block                                    81
# grades_run_block                                     87
# hits_allowed                                          1
# hurries_allowed                                       1
# non_spike_pass_block                                 63
# non_spike_pass_block_percentage                     100
# pass_block_percent                                  100
# pbe                                                98.4
# penalties                                             0
# pressures_allowed                                     2
# sacks_allowed                                         0
# snap_counts_block                                    92
# snap_counts_ce                                       92
# snap_counts_lg                                        0
# snap_counts_lt                                        0
# snap_counts_offense                                  92
# snap_counts_pass_block                               71
# snap_counts_pass_play                                71
# snap_counts_rg                                        0
# snap_counts_rt                                        0
# snap_counts_run_block                                21
# snap_counts_te                                        0
# week                                                  1
# year                                               2006
#
#                                                    3    \
# unique_id                        mattnelson_det_2006_1
# player_id                          mattnelson_det_2006
# unique_team_id                              det_2006_1
# team_id_impute                                det_2006
# player_name                                 mattnelson
# player_team                             mattnelson_det
# player                                      mattnelson
# position                                             t
# team_name                                          det
# player_game_count                                    1
# block_percent                                      100
# declined_penalties                                   1
# franchise_id                                        11
# grades_offense                                      52
# grades_pass_block                                 44.3
# grades_run_block                                  58.6
# hits_allowed                                         0
# hurries_allowed                                      5
# non_spike_pass_block                                63
# non_spike_pass_block_percentage                    100
# pass_block_percent                                 100
# pbe                                               94.4
# penalties                                            1
# pressures_allowed                                    6
# sacks_allowed                                        1
# snap_counts_block                                   92
# snap_counts_ce                                       0
# snap_counts_lg                                       0
# snap_counts_lt                                       0
# snap_counts_offense                                 92
# snap_counts_pass_block                              71
# snap_counts_pass_play                               71
# snap_counts_rg                                       0
# snap_counts_rt                                      92
# snap_counts_run_block                               21
# snap_counts_te                                       0
# week                                                 1
# year                                              2006
#
#                                                      4    \
# unique_id                        jonahjackson_det_2006_1
# player_id                          jonahjackson_det_2006
# unique_team_id                                det_2006_1
# team_id_impute                                  det_2006
# player_name                                 jonahjackson
# player_team                             jonahjackson_det
# player                                      jonahjackson
# position                                               g
# team_name                                            det
# player_game_count                                      1
# block_percent                                        100
# declined_penalties                                     0
# franchise_id                                          11
# grades_offense                                      56.3
# grades_pass_block                                   31.4
# grades_run_block                                    67.7
# hits_allowed                                           2
# hurries_allowed                                        6
# non_spike_pass_block                                  63
# non_spike_pass_block_percentage                      100
# pass_block_percent                                   100
# pbe                                                 92.1
# penalties                                              1
# pressures_allowed                                      9
# sacks_allowed                                          1
# snap_counts_block                                     92
# snap_counts_ce                                         0
# snap_counts_lg                                        92
# snap_counts_lt                                         0
# snap_counts_offense                                   92
# snap_counts_pass_block                                71
# snap_counts_pass_play                                 71
# snap_counts_rg                                         0
# snap_counts_rt                                         0
# snap_counts_run_block                                 21
# snap_counts_te                                         0
# week                                                   1
# year                                                2006
#
#                                                     5    \
# unique_id                        koltonmiller_lv_2006_1
# player_id                          koltonmiller_lv_2006
# unique_team_id                                lv_2006_1
# team_id_impute                                  lv_2006
# player_name                                koltonmiller
# player_team                             koltonmiller_lv
# player                                     koltonmiller
# position                                              t
# team_name                                            lv
# player_game_count                                     1
# block_percent                                       100
# declined_penalties                                    0
# franchise_id                                         23
# grades_offense                                     84.6
# grades_pass_block                                  87.5
# grades_run_block                                   76.4
# hits_allowed                                          0
# hurries_allowed                                       2
# non_spike_pass_block                                 59
# non_spike_pass_block_percentage                     100
# pass_block_percent                                  100
# pbe                                                98.3
# penalties                                             0
# pressures_allowed                                     2
# sacks_allowed                                         0
# snap_counts_block                                    86
# snap_counts_ce                                        0
# snap_counts_lg                                        0
# snap_counts_lt                                       86
# snap_counts_offense                                  86
# snap_counts_pass_block                               65
# snap_counts_pass_play                                65
# snap_counts_rg                                        0
# snap_counts_rt                                        0
# snap_counts_run_block                                21
# snap_counts_te                                        0
# week                                                  1
# year                                               2006
#
#                                                    6    \
# unique_id                        johnsimpson_lv_2006_1
# player_id                          johnsimpson_lv_2006
# unique_team_id                               lv_2006_1
# team_id_impute                                 lv_2006
# player_name                                johnsimpson
# player_team                             johnsimpson_lv
# player                                     johnsimpson
# position                                             g
# team_name                                           lv
# player_game_count                                    1
# block_percent                                      100
# declined_penalties                                   0
# franchise_id                                        23
# grades_offense                                    54.8
# grades_pass_block                                 46.2
# grades_run_block                                  58.2
# hits_allowed                                         1
# hurries_allowed                                      3
# non_spike_pass_block                                59
# non_spike_pass_block_percentage                    100
# pass_block_percent                                 100
# pbe                                               96.6
# penalties                                            0
# pressures_allowed                                    4
# sacks_allowed                                        0
# snap_counts_block                                   86
# snap_counts_ce                                       0
# snap_counts_lg                                      86
# snap_counts_lt                                       0
# snap_counts_offense                                 86
# snap_counts_pass_block                              65
# snap_counts_pass_play                               65
# snap_counts_rg                                       0
# snap_counts_rt                                       0
# snap_counts_run_block                               21
# snap_counts_te                                       0
# week                                                 1
# year                                              2006
#
#                                                        7    \
# unique_id                        alexleatherwood_lv_2006_1
# player_id                          alexleatherwood_lv_2006
# unique_team_id                                   lv_2006_1
# team_id_impute                                     lv_2006
# player_name                                alexleatherwood
# player_team                             alexleatherwood_lv
# player                                     alexleatherwood
# position                                                 t
# team_name                                               lv
# player_game_count                                        1
# block_percent                                          100
# declined_penalties                                       0
# franchise_id                                            23
# grades_offense                                        39.4
# grades_pass_block                                     34.1
# grades_run_block                                      60.7
# hits_allowed                                             1
# hurries_allowed                                          2
# non_spike_pass_block                                    59
# non_spike_pass_block_percentage                        100
# pass_block_percent                                     100
# pbe                                                   94.1
# penalties                                                2
# pressures_allowed                                        5
# sacks_allowed                                            2
# snap_counts_block                                       86
# snap_counts_ce                                           0
# snap_counts_lg                                           0
# snap_counts_lt                                           0
# snap_counts_offense                                     86
# snap_counts_pass_block                                  65
# snap_counts_pass_play                                   65
# snap_counts_rg                                           0
# snap_counts_rt                                          86
# snap_counts_run_block                                   21
# snap_counts_te                                           0
# week                                                     1
# year                                                  2006
#
#                                                   8    \
# unique_id                        andrejames_lv_2006_1
# player_id                          andrejames_lv_2006
# unique_team_id                              lv_2006_1
# team_id_impute                                lv_2006
# player_name                                andrejames
# player_team                             andrejames_lv
# player                                     andrejames
# position                                           ol
# team_name                                          lv
# player_game_count                                   1
# block_percent                                     100
# declined_penalties                                  0
# franchise_id                                       23
# grades_offense                                   35.6
# grades_pass_block                                61.7
# grades_run_block                                 28.5
# hits_allowed                                        1
# hurries_allowed                                     1
# non_spike_pass_block                               59
# non_spike_pass_block_percentage                   100
# pass_block_percent                                100
# pbe                                              98.3
# penalties                                           3
# pressures_allowed                                   2
# sacks_allowed                                       0
# snap_counts_block                                  86
# snap_counts_ce                                     86
# snap_counts_lg                                      0
# snap_counts_lt                                      0
# snap_counts_offense                                86
# snap_counts_pass_block                             65
# snap_counts_pass_play                              65
# snap_counts_rg                                      0
# snap_counts_rt                                      0
# snap_counts_run_block                              21
# snap_counts_te                                      0
# week                                                1
# year                                             2006
#
#                                                      9    ...  \
# unique_id                        jonfeliciano_buf_2006_1  ...
# player_id                          jonfeliciano_buf_2006  ...
# unique_team_id                                buf_2006_1  ...
# team_id_impute                                  buf_2006  ...
# player_name                                 jonfeliciano  ...
# player_team                             jonfeliciano_buf  ...
# player                                      jonfeliciano  ...
# position                                               g  ...
# team_name                                            buf  ...
# player_game_count                                      1  ...
# block_percent                                        100  ...
# declined_penalties                                     1  ...
# franchise_id                                           4  ...
# grades_offense                                      39.9  ...
# grades_pass_block                                   30.9  ...
# grades_run_block                                    44.1  ...
# hits_allowed                                           0  ...
# hurries_allowed                                        8  ...
# non_spike_pass_block                                  56  ...
# non_spike_pass_block_percentage                      100  ...
# pass_block_percent                                   100  ...
# pbe                                                 92.9  ...
# penalties                                              1  ...
# pressures_allowed                                      8  ...
# sacks_allowed                                          0  ...
# snap_counts_block                                     85  ...
# snap_counts_ce                                         0  ...
# snap_counts_lg                                        85  ...
# snap_counts_lt                                         0  ...
# snap_counts_offense                                   85  ...
# snap_counts_pass_block                                62  ...
# snap_counts_pass_play                                 62  ...
# snap_counts_rg                                         0  ...
# snap_counts_rt                                         0  ...
# snap_counts_run_block                                 23  ...
# snap_counts_te                                         0  ...
# week                                                   1  ...
# year                                                2006  ...
#
#                                                           183  \
# unique_id                        davidquessenberry_ten_2021_4
# player_id                          davidquessenberry_ten_2021
# unique_team_id                                     ten_2021_4
# team_id_impute                                       ten_2021
# player_name                                 davidquessenberry
# player_team                             davidquessenberry_ten
# player                                      davidquessenberry
# position                                                    t
# team_name                                                 ten
# player_game_count                                           1
# block_percent                                             100
# declined_penalties                                          0
# franchise_id                                               31
# grades_offense                                              0
# grades_pass_block                                           0
# grades_run_block                                            0
# hits_allowed                                                0
# hurries_allowed                                             0
# non_spike_pass_block                                        0
# non_spike_pass_block_percentage                             0
# pass_block_percent                                          0
# pbe                                                         0
# penalties                                                   0
# pressures_allowed                                           0
# sacks_allowed                                               0
# snap_counts_block                                           0
# snap_counts_ce                                              0
# snap_counts_lg                                              0
# snap_counts_lt                                              0
# snap_counts_offense                                         0
# snap_counts_pass_block                                      0
# snap_counts_pass_play                                       0
# snap_counts_rg                                              0
# snap_counts_rt                                              0
# snap_counts_run_block                                       0
# snap_counts_te                                              0
# week                                                        4
# year                                                     2021
#
#                                                       184  \
# unique_id                        rodgersaffold_ten_2021_4
# player_id                          rodgersaffold_ten_2021
# unique_team_id                                 ten_2021_4
# team_id_impute                                   ten_2021
# player_name                                 rodgersaffold
# player_team                             rodgersaffold_ten
# player                                      rodgersaffold
# position                                                g
# team_name                                             ten
# player_game_count                                       1
# block_percent                                         100
# declined_penalties                                      0
# franchise_id                                           31
# grades_offense                                          0
# grades_pass_block                                       0
# grades_run_block                                        0
# hits_allowed                                            0
# hurries_allowed                                         0
# non_spike_pass_block                                    0
# non_spike_pass_block_percentage                         0
# pass_block_percent                                      0
# pbe                                                     0
# penalties                                               0
# pressures_allowed                                       0
# sacks_allowed                                           0
# snap_counts_block                                       0
# snap_counts_ce                                          0
# snap_counts_lg                                          0
# snap_counts_lt                                          0
# snap_counts_offense                                     0
# snap_counts_pass_block                                  0
# snap_counts_pass_play                                   0
# snap_counts_rg                                          0
# snap_counts_rt                                          0
# snap_counts_run_block                                   0
# snap_counts_te                                          0
# week                                                    4
# year                                                 2021
#
#                                                     185  \
# unique_id                        aaronbrewer_ten_2021_4
# player_id                          aaronbrewer_ten_2021
# unique_team_id                               ten_2021_4
# team_id_impute                                 ten_2021
# player_name                                 aaronbrewer
# player_team                             aaronbrewer_ten
# player                                      aaronbrewer
# position                                              g
# team_name                                           ten
# player_game_count                                     1
# block_percent                                       100
# declined_penalties                                    0
# franchise_id                                         31
# grades_offense                                        0
# grades_pass_block                                     0
# grades_run_block                                      0
# hits_allowed                                          0
# hurries_allowed                                       0
# non_spike_pass_block                                  0
# non_spike_pass_block_percentage                       0
# pass_block_percent                                    0
# pbe                                                   0
# penalties                                             0
# pressures_allowed                                     0
# sacks_allowed                                         0
# snap_counts_block                                     0
# snap_counts_ce                                        0
# snap_counts_lg                                        0
# snap_counts_lt                                        0
# snap_counts_offense                                   0
# snap_counts_pass_block                                0
# snap_counts_pass_play                                 0
# snap_counts_rg                                        0
# snap_counts_rt                                        0
# snap_counts_run_block                                 0
# snap_counts_te                                        0
# week                                                  4
# year                                               2021
#
#                                                     186  \
# unique_id                        tysambrailo_ten_2021_4
# player_id                          tysambrailo_ten_2021
# unique_team_id                               ten_2021_4
# team_id_impute                                 ten_2021
# player_name                                 tysambrailo
# player_team                             tysambrailo_ten
# player                                      tysambrailo
# position                                              t
# team_name                                           ten
# player_game_count                                     1
# block_percent                                       100
# declined_penalties                                    0
# franchise_id                                         31
# grades_offense                                        0
# grades_pass_block                                     0
# grades_run_block                                      0
# hits_allowed                                          0
# hurries_allowed                                       0
# non_spike_pass_block                                  0
# non_spike_pass_block_percentage                       0
# pass_block_percent                                    0
# pbe                                                   0
# penalties                                             0
# pressures_allowed                                     0
# sacks_allowed                                         0
# snap_counts_block                                     0
# snap_counts_ce                                        0
# snap_counts_lg                                        0
# snap_counts_lt                                        0
# snap_counts_offense                                   0
# snap_counts_pass_block                                0
# snap_counts_pass_play                                 0
# snap_counts_rg                                        0
# snap_counts_rt                                        0
# snap_counts_run_block                                 0
# snap_counts_te                                        0
# week                                                  4
# year                                               2021
#
#                                                       187  \
# unique_id                        chaseroullier_was_2021_4
# player_id                          chaseroullier_was_2021
# unique_team_id                                 was_2021_4
# team_id_impute                                   was_2021
# player_name                                 chaseroullier
# player_team                             chaseroullier_was
# player                                      chaseroullier
# position                                               ol
# team_name                                             was
# player_game_count                                       1
# block_percent                                         100
# declined_penalties                                      0
# franchise_id                                           32
# grades_offense                                          0
# grades_pass_block                                       0
# grades_run_block                                        0
# hits_allowed                                            0
# hurries_allowed                                         0
# non_spike_pass_block                                    0
# non_spike_pass_block_percentage                         0
# pass_block_percent                                      0
# pbe                                                     0
# penalties                                               0
# pressures_allowed                                       0
# sacks_allowed                                           0
# snap_counts_block                                       0
# snap_counts_ce                                          0
# snap_counts_lg                                          0
# snap_counts_lt                                          0
# snap_counts_offense                                     0
# snap_counts_pass_block                                  0
# snap_counts_pass_play                                   0
# snap_counts_rg                                          0
# snap_counts_rt                                          0
# snap_counts_run_block                                   0
# snap_counts_te                                          0
# week                                                    4
# year                                                 2021
#
#                                                       188  \
# unique_id                        charleslenojr_was_2021_4
# player_id                          charleslenojr_was_2021
# unique_team_id                                 was_2021_4
# team_id_impute                                   was_2021
# player_name                                 charleslenojr
# player_team                             charleslenojr_was
# player                                      charleslenojr
# position                                                t
# team_name                                             was
# player_game_count                                       1
# block_percent                                         100
# declined_penalties                                      0
# franchise_id                                           32
# grades_offense                                          0
# grades_pass_block                                       0
# grades_run_block                                        0
# hits_allowed                                            0
# hurries_allowed                                         0
# non_spike_pass_block                                    0
# non_spike_pass_block_percentage                         0
# pass_block_percent                                      0
# pbe                                                     0
# penalties                                               0
# pressures_allowed                                       0
# sacks_allowed                                           0
# snap_counts_block                                       0
# snap_counts_ce                                          0
# snap_counts_lg                                          0
# snap_counts_lt                                          0
# snap_counts_offense                                     0
# snap_counts_pass_block                                  0
# snap_counts_pass_play                                   0
# snap_counts_rg                                          0
# snap_counts_rt                                          0
# snap_counts_run_block                                   0
# snap_counts_te                                          0
# week                                                    4
# year                                                 2021
#
#                                                      189  \
# unique_id                        ereckflowers_was_2021_4
# player_id                          ereckflowers_was_2021
# unique_team_id                                was_2021_4
# team_id_impute                                  was_2021
# player_name                                 ereckflowers
# player_team                             ereckflowers_was
# player                                      ereckflowers
# position                                               g
# team_name                                            was
# player_game_count                                      1
# block_percent                                        100
# declined_penalties                                     0
# franchise_id                                          32
# grades_offense                                         0
# grades_pass_block                                      0
# grades_run_block                                       0
# hits_allowed                                           0
# hurries_allowed                                        0
# non_spike_pass_block                                   0
# non_spike_pass_block_percentage                        0
# pass_block_percent                                     0
# pbe                                                    0
# penalties                                              0
# pressures_allowed                                      0
# sacks_allowed                                          0
# snap_counts_block                                      0
# snap_counts_ce                                         0
# snap_counts_lg                                         0
# snap_counts_lt                                         0
# snap_counts_offense                                    0
# snap_counts_pass_block                                 0
# snap_counts_pass_play                                  0
# snap_counts_rg                                         0
# snap_counts_rt                                         0
# snap_counts_run_block                                  0
# snap_counts_te                                         0
# week                                                   4
# year                                                2021
#
#                                                     190  \
# unique_id                        samuelcosmi_was_2021_4
# player_id                          samuelcosmi_was_2021
# unique_team_id                               was_2021_4
# team_id_impute                                 was_2021
# player_name                                 samuelcosmi
# player_team                             samuelcosmi_was
# player                                      samuelcosmi
# position                                              t
# team_name                                           was
# player_game_count                                     1
# block_percent                                       100
# declined_penalties                                    0
# franchise_id                                         32
# grades_offense                                        0
# grades_pass_block                                     0
# grades_run_block                                      0
# hits_allowed                                          0
# hurries_allowed                                       0
# non_spike_pass_block                                  0
# non_spike_pass_block_percentage                       0
# pass_block_percent                                    0
# pbe                                                   0
# penalties                                             0
# pressures_allowed                                     0
# sacks_allowed                                         0
# snap_counts_block                                     0
# snap_counts_ce                                        0
# snap_counts_lg                                        0
# snap_counts_lt                                        0
# snap_counts_offense                                   0
# snap_counts_pass_block                                0
# snap_counts_pass_play                                 0
# snap_counts_rg                                        0
# snap_counts_rt                                        0
# snap_counts_run_block                                 0
# snap_counts_te                                        0
# week                                                  4
# year                                               2021
#
#                                                        191  \
# unique_id                        brandonscherff_was_2021_4
# player_id                          brandonscherff_was_2021
# unique_team_id                                  was_2021_4
# team_id_impute                                    was_2021
# player_name                                 brandonscherff
# player_team                             brandonscherff_was
# player                                      brandonscherff
# position                                                 g
# team_name                                              was
# player_game_count                                        1
# block_percent                                          100
# declined_penalties                                       0
# franchise_id                                            32
# grades_offense                                           0
# grades_pass_block                                        0
# grades_run_block                                         0
# hits_allowed                                             0
# hurries_allowed                                          0
# non_spike_pass_block                                     0
# non_spike_pass_block_percentage                          0
# pass_block_percent                                       0
# pbe                                                      0
# penalties                                                0
# pressures_allowed                                        0
# sacks_allowed                                            0
# snap_counts_block                                        0
# snap_counts_ce                                           0
# snap_counts_lg                                           0
# snap_counts_lt                                           0
# snap_counts_offense                                      0
# snap_counts_pass_block                                   0
# snap_counts_pass_play                                    0
# snap_counts_rg                                           0
# snap_counts_rt                                           0
# snap_counts_run_block                                    0
# snap_counts_te                                           0
# week                                                     4
# year                                                  2021
#
#                                                       192
# unique_id                        wesschweitzer_was_2021_4
# player_id                          wesschweitzer_was_2021
# unique_team_id                                 was_2021_4
# team_id_impute                                   was_2021
# player_name                                 wesschweitzer
# player_team                             wesschweitzer_was
# player                                      wesschweitzer
# position                                                g
# team_name                                             was
# player_game_count                                       1
# block_percent                                         100
# declined_penalties                                      0
# franchise_id                                           32
# grades_offense                                          0
# grades_pass_block                                       0
# grades_run_block                                        0
# hits_allowed                                            0
# hurries_allowed                                         0
# non_spike_pass_block                                    0
# non_spike_pass_block_percentage                         0
# pass_block_percent                                      0
# pbe                                                     0
# penalties                                               0
# pressures_allowed                                       0
# sacks_allowed                                           0
# snap_counts_block                                       0
# snap_counts_ce                                          0
# snap_counts_lg                                          0
# snap_counts_lt                                          0
# snap_counts_offense                                     0
# snap_counts_pass_block                                  0
# snap_counts_pass_play                                   0
# snap_counts_rg                                          0
# snap_counts_rt                                          0
# snap_counts_run_block                                   0
# snap_counts_te                                          0
# week                                                    4
# year                                                 2021
#
# [38 rows x 46515 columns]

# %%
## Get rid of nonsense ##
roll_rbs= roll_rbs[~roll_rbs['year'].isin(['nan'])]
roll_qbs= roll_qbs[~roll_qbs['year'].isin(['nan'])]
roll_wr_recs= roll_wr_recs[~roll_wr_recs['year'].isin(['nan'])]
roll_oline= roll_oline[~roll_oline['year'].isin(['nan'])]
roll_defense= roll_defense[~roll_defense['year'].isin(['nan'])]

## Subset into defense positional groups ##
def_lineman = roll_defense[roll_defense['position'].isin(['ed','di'])]
def_linebackers = roll_defense[roll_defense['position'].isin(['lb'])]
def_dbs = roll_defense[roll_defense['position'].isin(['cb','s'])]

# %%
roll_qbs_rush = roll_rbs[roll_rbs['position'].isin(['qb'])]
roll_rbs = roll_rbs[~roll_rbs.index.isin(roll_qbs_rush.index)]


roll_te_rec = roll_wr_recs[roll_wr_recs['position'].isin(['te'])]
#roll_wr_recs = roll_wr_recs[~roll_wr_recs.index.isin(roll_te_rec.index)]

roll_rb_rec = roll_wr_recs[roll_wr_recs['position'].isin(['hb'])]
#roll_wr_recs = roll_wr_recs[~roll_wr_recs.index.isin(roll_rb_rec.index)]

roll_wr_recs = roll_wr_recs[roll_wr_recs['position'].isin(['wr'])]

# %%
profiles = pd.read_csv(cur_dir+'/other_data/pff_player_pros.csv')
profiles.head().T
rb_df = profiles[['unique_id','height','wt','speed','draft_yr','round','selection']]
te_df = profiles[['unique_id','height','wt','speed','draft_yr','round','selection']]
qb_df = profiles[['unique_id','height','wt','speed','draft_yr','round','selection']]
wr_df = profiles[['unique_id','height','wt','speed','draft_yr','round','selection']]
ol_df = profiles[['unique_id','height','wt','speed','draft_yr','round','selection']]
def_dl = profiles[['unique_id','height','wt','speed','draft_yr','round','selection']]
def_lb = profiles[['unique_id','height','wt','speed','draft_yr','round','selection']]
def_db = profiles[['unique_id','height','wt','speed','draft_yr','round','selection']]

# %%
roll_qbs
# Out:
#                          unique_id                  player_id unique_team_id  \
# 1          aaronbrooks_oak_2006_11       aaronbrooks_oak_2006    oak_2006_11
# 2          aaronbrooks_oak_2006_12       aaronbrooks_oak_2006    oak_2006_12
# 3          aaronbrooks_oak_2006_13       aaronbrooks_oak_2006    oak_2006_13
# 4          aaronbrooks_oak_2006_14       aaronbrooks_oak_2006    oak_2006_14
# 5          aaronbrooks_oak_2006_15       aaronbrooks_oak_2006    oak_2006_15
# ...                            ...                        ...            ...
# 8884  zachmettenberger_ten_2015_16  zachmettenberger_ten_2015    ten_2015_16
# 8885  zachmettenberger_ten_2015_17  zachmettenberger_ten_2015    ten_2015_17
# 8887         zachwilson_nyj_2021_2        zachwilson_nyj_2021     nyj_2021_2
# 8888         zachwilson_nyj_2021_3        zachwilson_nyj_2021     nyj_2021_3
# 8889         zachwilson_nyj_2021_4        zachwilson_nyj_2021     nyj_2021_4
#
#      team_id_impute       player_name           player_team            player  \
# 1          oak_2006       aaronbrooks       aaronbrooks_oak       aaronbrooks
# 2          oak_2006       aaronbrooks       aaronbrooks_oak       aaronbrooks
# 3          oak_2006       aaronbrooks       aaronbrooks_oak       aaronbrooks
# 4          oak_2006       aaronbrooks       aaronbrooks_oak       aaronbrooks
# 5          oak_2006       aaronbrooks       aaronbrooks_oak       aaronbrooks
# ...             ...               ...                   ...               ...
# 8884       ten_2015  zachmettenberger  zachmettenberger_ten  zachmettenberger
# 8885       ten_2015  zachmettenberger  zachmettenberger_ten  zachmettenberger
# 8887       nyj_2021        zachwilson        zachwilson_nyj        zachwilson
# 8888       nyj_2021        zachwilson        zachwilson_nyj        zachwilson
# 8889       nyj_2021        zachwilson        zachwilson_nyj        zachwilson
#
#      position team_name  player_game_count  ...  scrambles    spikes  \
# 1          qb       oak                1.0  ...   3.000000  0.000000
# 2          qb       oak                1.0  ...   3.500000  0.000000
# 3          qb       oak                1.0  ...   3.333333  0.000000
# 4          qb       oak                1.0  ...   3.000000  0.666667
# 5          qb       oak                1.0  ...   2.333333  0.666667
# ...       ...       ...                ...  ...        ...       ...
# 8884       qb       ten                1.0  ...   0.333333  0.000000
# 8885       qb       ten                1.0  ...   0.333333  0.000000
# 8887       qb       nyj                1.0  ...   0.000000  0.000000
# 8888       qb       nyj                1.0  ...   1.000000  0.000000
# 8889       qb       nyj                1.0  ...   0.666667  0.000000
#
#       thrown_aways  touchdowns  turnover_worthy_plays  twp_rate       yards  \
# 1         1.000000    0.000000               2.000000  8.000000   68.000000
# 2         2.000000    0.500000               1.500000  5.700000  123.500000
# 3         1.666667    0.666667               1.666667  5.400000  144.666667
# 4         2.000000    0.666667               1.666667  4.033333  201.333333
# 5         1.333333    0.666667               1.333333  2.900000  208.000000
# ...            ...         ...                    ...       ...         ...
# 8884      0.000000    1.000000               2.666667  7.466667  200.000000
# 8885      0.666667    1.000000               2.666667  6.700000  215.666667
# 8887      1.000000    2.000000               3.000000  6.500000  258.000000
# 8888      0.500000    1.000000               2.500000  5.600000  234.000000
# 8889      1.000000    0.666667               2.000000  4.533333  209.333333
#
#            ypa  week    year
# 1     4.900000   1.0  2006.0
# 2     6.500000   6.0  2006.0
# 3     6.400000   8.0  2006.0
# 4     6.666667  12.0  2006.0
# 5     5.666667  13.0  2006.0
# ...        ...   ...     ...
# 8884  6.466667  10.0  2015.0
# 8885  6.233333  13.0  2015.0
# 8887  7.000000   1.0  2021.0
# 8888  6.700000   1.5  2021.0
# 8889  6.000000   2.0  2021.0
#
# [7752 rows x 49 columns]

# %% [markdown]
# ### RB Position Weights and Stats Groupby's

# %%
roll_rbs.columns
# Out:
# Index(['unique_id', 'player_id', 'unique_team_id', 'team_id_impute',
#        'player_name', 'player_team', 'player', 'position', 'team_name',
#        'player_game_count', 'attempts', 'avoided_tackles',
#        'breakaway_attempts', 'breakaway_percent', 'breakaway_yards',
#        'declined_penalties', 'designed_yards', 'drops', 'elu_recv_mtf',
#        'elu_rush_mtf', 'elu_yco', 'elusive_rating', 'explosive', 'first_downs',
#        'franchise_id', 'fumbles', 'gap_attempts', 'grades_offense',
#        'grades_offense_penalty', 'grades_pass', 'grades_pass_block',
#        'grades_pass_route', 'grades_run', 'grades_run_block', 'longest',
#        'penalties', 'rec_yards', 'receptions', 'routes', 'run_plays',
#        'scramble_yards', 'scrambles', 'targets', 'total_touches', 'touchdowns',
#        'yards', 'yards_after_contact', 'yco_attempt', 'ypa', 'yprr',
#        'zone_attempts', 'week', 'year'],
#       dtype='object')

# %%
## make sure we aren't weighting w/a 0 value (non-designed runs are cancelled ##
rb_df.columns = [str(col) + '_rbs' for col in rb_df.columns]
roll_rbs = pd.merge(roll_rbs, rb_df, left_on='player_id', right_on='unique_id_rbs', how='left')
roll_rbs.drop_duplicates(subset=['unique_id'], keep='first', inplace=True)

## make sure we aren't weighting w/a 0 value (non-designed runs are cancelled ##
def rush_att(nData):
    if nData['attempts'] == 0:
        return 1
    else:
        return nData['attempts']
roll_rbs['attempts'] = roll_rbs.apply(lambda df: rush_att(df), axis=1)  
roll_qbs_rush['attempts'] = roll_qbs_rush.apply(lambda df: rush_att(df), axis=1)

def game_combine(data=None):
    data_cols = data.select_dtypes(include=[np.number])
    num_cols = data_cols[data_cols.columns.drop(list(data_cols.filter(regex=r'grades_|week|year|team_id|height|wt|speed|draft_yr|round|selection|franchise')))].columns.tolist()
    group = data.groupby(data['unique_team_id'])[num_cols].sum().reset_index()
    return group
   
rb_sums = game_combine(data=roll_rbs)
qbs_rush_sums = game_combine(data=roll_qbs_rush)


def weighted(nData, snap_Var='attempts'):
    pff_cols = nData.filter(regex='grades_').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)
   
def pros(nData, snap_Var='attempts'):
    pro_cols = nData.filter(regex='height|wt|speed|draft_yr|round|selection').columns
    return pd.Series(np.average(nData[pro_cols], weights=nData[snap_Var], axis=0), pro_cols)

roll_rbs_avgs=roll_rbs.fillna(roll_rbs.mean())
rb_pro_avgs = roll_rbs_avgs.groupby('unique_team_id').apply(pros).reset_index()

roll_rbs_zeros=roll_rbs.fillna(0.1)
roll_qbs_zeros=roll_qbs_rush.fillna(0.1)

rb_pff_avgs = roll_rbs_zeros.groupby('unique_team_id').apply(weighted).reset_index()
qb_rush_pff_avgs = roll_qbs_zeros.groupby('unique_team_id').apply(weighted).reset_index()

rb_stats = pd.merge(rb_pff_avgs, rb_pro_avgs, on='unique_team_id', how='left').merge(rb_sums, on='unique_team_id', how='left')
rb_stats.head(n=2).T


qb_rush_stats = pd.merge(qb_rush_pff_avgs, qbs_rush_sums, on='unique_team_id', how='left')

# %%
roll_rbs.groupby('unique_team_id').apply(weighted).reset_index()
# Out:
#      unique_team_id  grades_offense  grades_offense_penalty  grades_pass  \
# 0       ari_2006_10       46.565432               74.860905    64.826796
# 1       ari_2006_11       52.180303               75.333333    64.826796
# 2       ari_2006_12       60.490104               75.264583    64.826796
# 3       ari_2006_13       61.080556               73.931250    64.826796
# 4       ari_2006_14       57.584742               73.977230    64.826796
# ...             ...             ...                     ...          ...
# 7288     was_2020_7       65.191358               74.830247    64.826796
# 7289     was_2020_9       69.146914               76.449383    64.826796
# 7290     was_2021_2       51.100000                3.614286    64.826796
# 7291     was_2021_3       57.096053               44.044737    64.826796
# 7292     was_2021_4       58.741509               54.905660    64.826796
#
#       grades_pass_block  grades_pass_route  grades_run  grades_run_block
# 0             80.403223          60.092701   44.837860         60.448012
# 1             80.800119          62.518868   48.923333         60.219286
# 2             78.083333          64.738021   58.083854         60.233477
# 3             73.947545          65.206079   58.175694         60.080049
# 4             72.923709          61.717840   56.220657         60.287125
# ...                 ...                ...         ...               ...
# 7288          59.305335          73.077778   59.622222         59.777364
# 7289          40.913580          63.306173   68.056790         59.335900
# 7290          65.965530          47.314286   57.371429         60.605137
# 7291          42.746192          52.142105   63.177632         60.271487
# 7292          53.244002          52.415094   63.305660         60.176212
#
# [7293 rows x 8 columns]

# %%
rb_stats.to_csv(cur_dir+'/other_data/roll_rbs.csv')

# %%
roll_qbs_zeros.head().T
# Out:
#                                              1                        2  \
# unique_id               aaronbrooks_oak_2006_2  aaronbrooks_oak_2006_11
# player_id                 aaronbrooks_oak_2006     aaronbrooks_oak_2006
# unique_team_id                      oak_2006_2              oak_2006_11
# team_id_impute                        oak_2006                 oak_2006
# player_name                        aaronbrooks              aaronbrooks
# player_team                    aaronbrooks_oak          aaronbrooks_oak
# player                             aaronbrooks              aaronbrooks
# position                                    qb                       qb
# team_name                                  oak                      oak
# player_game_count                            1                        1
# attempts                                     1                        1
# avoided_tackles                              0                        0
# breakaway_attempts                           0                        0
# breakaway_percent                            0                  5.84834
# breakaway_yards                              0                        0
# declined_penalties                           0                        0
# designed_yards                               0                        0
# drops                                        0                        0
# elu_recv_mtf                                 0                        0
# elu_rush_mtf                                 0                        0
# elu_yco                                16.7549                  8.37747
# elusive_rating                             100                       50
# explosive                                    2                        1
# first_downs                                  2                        1
# franchise_id                                23                       23
# fumbles                                      0                        1
# gap_attempts                                 0                        0
# grades_offense                            43.4                     30.2
# grades_offense_penalty                    76.8                       73
# grades_pass                               38.8                  51.8134
# grades_pass_block                      65.0488                  65.0488
# grades_pass_route                      60.9585                  60.9585
# grades_run                                68.5                    46.85
# grades_run_block                            60                       60
# longest                                     14                        7
# penalties                                    0                        0
# rec_yards                                    0                        0
# receptions                                   0                        0
# routes                                       0                        0
# run_plays                                   10                        7
# scramble_yards                              27                     13.5
# scrambles                                    3                      1.5
# targets                                      0                        0
# total_touches                                0                        1
# touchdowns                                   0                        0
# yards                                       27                     13.5
# yards_after_contact                         12                        6
# yco_attempt                                  4                        2
# ypa                                          9                      4.5
# yprr                                   1.24339                  1.24339
# zone_attempts                                0                        0
# week                                         1                      1.5
# year                                      2006                     2006
#
#                                               3                        4  \
# unique_id               aaronbrooks_oak_2006_12  aaronbrooks_oak_2006_13
# player_id                  aaronbrooks_oak_2006     aaronbrooks_oak_2006
# unique_team_id                      oak_2006_12              oak_2006_13
# team_id_impute                         oak_2006                 oak_2006
# player_name                         aaronbrooks              aaronbrooks
# player_team                     aaronbrooks_oak          aaronbrooks_oak
# player                              aaronbrooks              aaronbrooks
# position                                     qb                       qb
# team_name                                   oak                      oak
# player_game_count                             1                        1
# attempts                                      1                  1.33333
# avoided_tackles                        0.333333                        1
# breakaway_attempts                            0                        0
# breakaway_percent                       3.89889                  3.89889
# breakaway_yards                               0                        0
# declined_penalties                            0                        0
# designed_yards                         -2.33333                       -1
# drops                                         0                        0
# elu_recv_mtf                                  0                        0
# elu_rush_mtf                                  0                        0
# elu_yco                                 5.58498                        2
# elusive_rating                          33.3333                        0
# explosive                                     1                 0.666667
# first_downs                                   1                 0.333333
# franchise_id                                 23                       23
# fumbles                                       1                        1
# gap_attempts                                  0                        0
# grades_offense                             48.5                  56.3333
# grades_offense_penalty                  74.9333                  49.3333
# grades_pass                             63.0089                  71.8756
# grades_pass_block                       65.0488                  65.0488
# grades_pass_route                       60.9585                  60.9585
# grades_run                              51.8333                     52.1
# grades_run_block                             60                       60
# longest                                 12.3333                  11.3333
# penalties                                     0                 0.333333
# rec_yards                                     0                        0
# receptions                                    0                        0
# routes                                        0                        0
# run_plays                                    15                  19.6667
# scramble_yards                          20.3333                  19.6667
# scrambles                               2.33333                  2.33333
# targets                                       0                        0
# total_touches                                 1                  1.33333
# touchdowns                                    0                        0
# yards                                        18                  18.6667
# yards_after_contact                           9                  17.6667
# yco_attempt                             2.33333                  4.16667
# ypa                                         4.8                  4.23333
# yprr                                    1.24339                  1.24339
# zone_attempts                                 0                        0
# week                                    4.66667                  8.33333
# year                                       2006                     2006
#
#                                               5
# unique_id               aaronbrooks_oak_2006_14
# player_id                  aaronbrooks_oak_2006
# unique_team_id                      oak_2006_14
# team_id_impute                         oak_2006
# player_name                         aaronbrooks
# player_team                     aaronbrooks_oak
# player                              aaronbrooks
# position                                     qb
# team_name                                   oak
# player_game_count                             1
# attempts                                      1
# avoided_tackles                               1
# breakaway_attempts                            0
# breakaway_percent                             0
# breakaway_yards                               0
# declined_penalties                            0
# designed_yards                        -0.333333
# drops                                         0
# elu_recv_mtf                                  0
# elu_rush_mtf                                  0
# elu_yco                                 2.66667
# elusive_rating                                0
# explosive                              0.666667
# first_downs                            0.666667
# franchise_id                                 23
# fumbles                                0.333333
# gap_attempts                           0.333333
# grades_offense                          68.2333
# grades_offense_penalty                  52.8333
# grades_pass                                  69
# grades_pass_block                       65.0488
# grades_pass_route                       60.9585
# grades_run                              58.9333
# grades_run_block                             60
# longest                                 14.3333
# penalties                              0.666667
# rec_yards                                     0
# receptions                                    0
# routes                                        0
# run_plays                                    27
# scramble_yards                          23.3333
# scrambles                                     3
# targets                                       0
# total_touches                                 1
# touchdowns                                    0
# yards                                        23
# yards_after_contact                     20.6667
# yco_attempt                             5.16667
# ypa                                     5.66667
# yprr                                    1.24339
# zone_attempts                                 0
# week                                         12
# year                                       2006

# %% [markdown]
# ### QB Position Weights and Stats Groupby's

# %%
qb_df.columns = [str(col) + '_qbs' for col in qb_df.columns]
roll_qbs = pd.merge(roll_qbs, qb_df, left_on='player_id', right_on='unique_id_qbs', how='left')
roll_qbs.drop_duplicates(subset=['unique_id'], keep='first', inplace=True)

def pass_att(nData):
    if nData['dropbacks'] == 0:
        return 1
    else:
        return nData['dropbacks']
roll_qbs['dropbacks'] = roll_qbs.apply(lambda df: pass_att(df), axis=1)   

def weighted(nData, snap_Var='dropbacks'):
    pff_cols = nData.filter(like='grades_').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)

def pros(nData, snap_Var='dropbacks'):
    pro_cols = nData.filter(regex='height|wt|speed|draft_yr|round|selection').columns
    return pd.Series(np.average(nData[pro_cols], weights=nData[snap_Var], axis=0), pro_cols)

roll_qbs_avgs=roll_qbs.fillna(roll_qbs.mean())
qb_pro_avgs = roll_qbs_avgs.groupby('unique_team_id').apply(pros).reset_index()

roll_qbs_zeros=roll_qbs.fillna(0.1)
qb_pff_avgs = roll_qbs_zeros.groupby('unique_team_id').apply(weighted).reset_index()

qb_sums = game_combine(data=roll_qbs)

qb_stats = pd.merge(qb_pff_avgs, qb_pro_avgs, on='unique_team_id', how='left').merge(qb_sums, on='unique_team_id', how='left')
qb_stats.head().T
# Out:
#                                  0            1            2            3  \
# unique_team_id         ari_2006_10  ari_2006_11  ari_2006_12  ari_2006_13
# grades_hands_fumble           79.2      62.6333         45.7         46.2
# grades_offense                47.1      49.0333         58.6      66.4333
# grades_pass                49.1667         50.5         59.8      66.6333
# grades_run                 55.1893      58.0667      59.2667      59.8559
# height_qbs                      77           77           77           77
# wt_qbs                         230          230          230          230
# speed_qbs                      4.9          4.9          4.9          4.9
# draft_yr_qbs                  2006         2006         2006         2006
# round_qbs                        1            1            1            1
# selection_qbs                   10           10           10           10
# player_game_count                1            1            1            1
# accuracy_percent           53.4667      51.8333      61.4667         69.6
# aimed_passes               33.3333      32.6667      31.3333      36.3333
# attempts                   36.3333           35           34      39.3333
# avg_depth_of_target        8.83333      9.96667          9.2      10.2667
# avg_time_to_throw          2.73333         2.89         2.72         2.68
# bats                             2     0.666667     0.666667     0.666667
# big_time_throws           0.666667      1.33333            2      2.66667
# btt_rate                       1.9      3.53333      5.83333      6.86667
# completion_percent            45.9         44.4         52.7      59.6333
# completions                     17      15.6667      17.6667      23.3333
# declined_penalties               0            0            0            0
# def_gen_pressures          16.6667      16.6667      14.3333      18.3333
# drop_rate                  6.53333      8.13333      7.43333      7.06667
# dropbacks                  39.6667      38.6667      37.6667      42.3333
# drops                            1      1.33333      1.33333            2
# first_downs                10.3333      9.66667           11      13.6667
# hit_as_threw              0.666667            1      1.33333            1
# interceptions                    1      1.66667            1      1.33333
# passing_snaps              40.6667      40.6667           40      44.6667
# penalties                 0.666667     0.666667     0.333333     0.333333
# pressure_to_sack_rate      16.9667      16.9667      14.4333      6.16667
# qb_rating                  58.8667      45.2333      67.0333      75.1333
# sack_percent                   6.9      6.96667      5.23333      2.43333
# sacks                      2.66667      2.66667            2            1
# scrambles                 0.666667            1      1.33333      1.33333
# spikes                           0     0.333333     0.333333     0.666667
# thrown_aways              0.333333     0.333333     0.333333     0.666667
# touchdowns                       1     0.333333     0.666667     0.666667
# turnover_worthy_plays      2.33333      2.33333      1.33333      1.33333
# twp_rate                   5.83333      5.83333      3.13333      2.93333
# yards                      197.333          192          202      284.667
# ypa                        5.43333          5.5      6.06667          7.2
#
#                                  4
# unique_team_id         ari_2006_14
# grades_hands_fumble             62
# grades_offense                72.6
# grades_pass                73.1667
# grades_run                 56.9785
# height_qbs                      77
# wt_qbs                         230
# speed_qbs                      4.9
# draft_yr_qbs                  2006
# round_qbs                        1
# selection_qbs                   10
# player_game_count                1
# accuracy_percent              72.2
# aimed_passes               32.6667
# attempts                   34.6667
# avg_depth_of_target        9.86667
# avg_time_to_throw          2.59667
# bats                      0.333333
# big_time_throws            2.33333
# btt_rate                   6.46667
# completion_percent         62.9333
# completions                21.6667
# declined_penalties               0
# def_gen_pressures          15.6667
# drop_rate                  7.56667
# dropbacks                  37.3333
# drops                            2
# first_downs                13.6667
# hit_as_threw              0.666667
# interceptions             0.666667
# passing_snaps              39.6667
# penalties                 0.333333
# pressure_to_sack_rate      7.63333
# qb_rating                  92.6667
# sack_percent               2.93333
# sacks                            1
# scrambles                        1
# spikes                    0.333333
# thrown_aways              0.666667
# touchdowns                       1
# turnover_worthy_plays     0.666667
# twp_rate                       1.8
# yards                      274.667
# ypa                            7.9

# %%
qb_stats.tail().T
# Out:
#                              7188        7189        7190        7191  \
# unique_team_id         was_2020_7  was_2020_9  was_2021_2  was_2021_3
# grades_hands_fumble         52.45     44.8262        75.4        78.1
# grades_offense               61.9     53.1569        46.9       60.15
# grades_pass                  58.8     52.6517        50.3        62.7
# grades_run                  63.65     61.2217        49.1       50.35
# height_qbs                75.2906     75.2906          73          73
# wt_qbs                    224.918     224.918         205         205
# speed_qbs                 4.82812     4.82812     4.82812     4.82812
# draft_yr_qbs              2007.19     2007.19        2015        2015
# round_qbs                 2.88495     2.88495          10          10
# selection_qbs             73.8533     73.8533         300         300
# player_game_count               1           2           1           1
# accuracy_percent             85.2       138.5        85.7       83.75
# aimed_passes                   25     39.6667          14          29
# attempts                     27.5     43.6667          15        30.5
# avg_depth_of_target           4.3     11.5667         7.9           8
# avg_time_to_throw            2.74     5.27333        2.88        2.64
# bats                          0.5     1.33333           0           0
# big_time_throws                 1           1           0         1.5
# btt_rate                      2.2     2.66667           0        3.15
# completion_percent           71.5     120.567        73.3        73.6
# completions                    20     27.3333          11        22.5
# declined_penalties              0           0           0           0
# def_gen_pressures              10     19.3333           6           8
# drop_rate                       5     5.43333         8.3        6.95
# dropbacks                    31.5     54.3333          18          34
# drops                         0.5    0.666667           1         1.5
# first_downs                  10.5          12           7          10
# hit_as_threw                    0    0.333333           0           0
# interceptions                 0.5    0.333333           0         0.5
# passing_snaps                  34          57          21        36.5
# penalties                     0.5    0.666667           0           0
# pressure_to_sack_rate          30     92.7667           0           5
# qb_rating                    90.4         156       119.3       109.4
# sack_percent                 9.45     33.6667           0           1
# sacks                         2.5     8.33333           0         0.5
# scrambles                     1.5     2.33333           3           3
# spikes                          0           0           0         0.5
# thrown_aways                    2     2.33333           1           1
# touchdowns                      1     1.33333           1         1.5
# turnover_worthy_plays           1           2           0           0
# twp_rate                        2         6.6           0           0
# yards                         177     219.667         122         229
# ypa                           6.2     8.93333         8.1         7.7
#
#                              7192
# unique_team_id         was_2021_4
# grades_hands_fumble       78.2667
# grades_offense            53.3667
# grades_pass                  55.5
# grades_run                52.3667
# height_qbs                     73
# wt_qbs                        205
# speed_qbs                 4.82812
# draft_yr_qbs                 2015
# round_qbs                      10
# selection_qbs                 300
# player_game_count               1
# accuracy_percent          79.4333
# aimed_passes              27.3333
# attempts                  28.3333
# avg_depth_of_target       7.76667
# avg_time_to_throw            3.04
# bats                            0
# big_time_throws                 1
# btt_rate                      2.1
# completion_percent           68.5
# completions               19.6667
# declined_penalties              0
# def_gen_pressures               9
# drop_rate                    10.5
# dropbacks                      33
# drops                           2
# first_downs               9.66667
# hit_as_threw                    0
# interceptions                   1
# passing_snaps             35.6667
# penalties                0.333333
# pressure_to_sack_rate     6.36667
# qb_rating                    99.8
# sack_percent              1.73333
# sacks                    0.666667
# scrambles                       4
# spikes                   0.333333
# thrown_aways             0.666667
# touchdowns                1.66667
# turnover_worthy_plays           1
# twp_rate                  2.93333
# yards                     223.333
# ypa                       8.06667

# %%
qb_sums
# Out:
#      unique_team_id  player_game_count  accuracy_percent  aimed_passes  \
# 0       ari_2006_10                1.0         53.466667     33.333333
# 1       ari_2006_11                1.0         51.833333     32.666667
# 2       ari_2006_12                1.0         61.466667     31.333333
# 3       ari_2006_13                1.0         69.600000     36.333333
# 4       ari_2006_14                1.0         72.200000     32.666667
# ...             ...                ...               ...           ...
# 7188     was_2020_7                1.0         85.200000     25.000000
# 7189     was_2020_9                2.0        138.500000     39.666667
# 7190     was_2021_2                1.0         85.700000     14.000000
# 7191     was_2021_3                1.0         83.750000     29.000000
# 7192     was_2021_4                1.0         79.433333     27.333333
#
#        attempts  avg_depth_of_target  avg_time_to_throw      bats  \
# 0     36.333333             8.833333           2.733333  2.000000
# 1     35.000000             9.966667           2.890000  0.666667
# 2     34.000000             9.200000           2.720000  0.666667
# 3     39.333333            10.266667           2.680000  0.666667
# 4     34.666667             9.866667           2.596667  0.333333
# ...         ...                  ...                ...       ...
# 7188  27.500000             4.300000           2.740000  0.500000
# 7189  43.666667            11.566667           5.273333  1.333333
# 7190  15.000000             7.900000           2.880000  0.000000
# 7191  30.500000             8.000000           2.640000  0.000000
# 7192  28.333333             7.766667           3.040000  0.000000
#
#       big_time_throws  btt_rate  ...  sack_percent     sacks  scrambles  \
# 0            0.666667  1.900000  ...      6.900000  2.666667   0.666667
# 1            1.333333  3.533333  ...      6.966667  2.666667   1.000000
# 2            2.000000  5.833333  ...      5.233333  2.000000   1.333333
# 3            2.666667  6.866667  ...      2.433333  1.000000   1.333333
# 4            2.333333  6.466667  ...      2.933333  1.000000   1.000000
# ...               ...       ...  ...           ...       ...        ...
# 7188         1.000000  2.200000  ...      9.450000  2.500000   1.500000
# 7189         1.000000  2.666667  ...     33.666667  8.333333   2.333333
# 7190         0.000000  0.000000  ...      0.000000  0.000000   3.000000
# 7191         1.500000  3.150000  ...      1.000000  0.500000   3.000000
# 7192         1.000000  2.100000  ...      1.733333  0.666667   4.000000
#
#         spikes  thrown_aways  touchdowns  turnover_worthy_plays  twp_rate  \
# 0     0.000000      0.333333    1.000000               2.333333  5.833333
# 1     0.333333      0.333333    0.333333               2.333333  5.833333
# 2     0.333333      0.333333    0.666667               1.333333  3.133333
# 3     0.666667      0.666667    0.666667               1.333333  2.933333
# 4     0.333333      0.666667    1.000000               0.666667  1.800000
# ...        ...           ...         ...                    ...       ...
# 7188  0.000000      2.000000    1.000000               1.000000  2.000000
# 7189  0.000000      2.333333    1.333333               2.000000  6.600000
# 7190  0.000000      1.000000    1.000000               0.000000  0.000000
# 7191  0.500000      1.000000    1.500000               0.000000  0.000000
# 7192  0.333333      0.666667    1.666667               1.000000  2.933333
#
#            yards       ypa
# 0     197.333333  5.433333
# 1     192.000000  5.500000
# 2     202.000000  6.066667
# 3     284.666667  7.200000
# 4     274.666667  7.900000
# ...          ...       ...
# 7188  177.000000  6.200000
# 7189  219.666667  8.933333
# 7190  122.000000  8.100000
# 7191  229.000000  7.700000
# 7192  223.333333  8.066667
#
# [7193 rows x 34 columns]

# %% [markdown]
# ### WR Position Weights and Stats Groupby's

# %%
roll_wr_recs.columns
# Out:
# Index(['unique_id', 'player_id', 'unique_team_id', 'team_id_impute',
#        'player_name', 'player_team', 'player', 'position', 'team_name',
#        'player_game_count', 'avg_depth_of_target', 'avoided_tackles',
#        'caught_percent', 'contested_catch_rate', 'contested_receptions',
#        'contested_targets', 'declined_penalties', 'drop_rate', 'drops',
#        'first_downs', 'franchise_id', 'fumbles', 'grades_hands_drop',
#        'grades_hands_fumble', 'grades_offense', 'grades_pass_block',
#        'grades_pass_route', 'inline_rate', 'inline_snaps', 'interceptions',
#        'longest', 'pass_block_rate', 'pass_blocks', 'pass_plays', 'penalties',
#        'receptions', 'route_rate', 'routes', 'slot_rate', 'slot_snaps',
#        'targeted_qb_rating', 'targets', 'touchdowns', 'wide_rate',
#        'wide_snaps', 'yards', 'yards_after_catch',
#        'yards_after_catch_per_reception', 'yards_per_reception', 'yprr',
#        'week', 'year'],
#       dtype='object')

# %%
wr_df.columns = [str(col) + '_wrs' for col in wr_df.columns]
roll_wr_recs = pd.merge(roll_wr_recs, wr_df, left_on='player_id', right_on='unique_id_wrs', how='left')
te_df.columns = [str(col) + '_tes' for col in te_df.columns]
roll_te_rec = pd.merge(roll_te_rec, te_df, left_on='player_id', right_on='unique_id_tes', how='left')

roll_wr_recs.drop_duplicates(subset=['unique_id'], keep='first', inplace=True)
roll_te_rec.drop_duplicates(subset=['unique_id'], keep='first', inplace=True)


def pass_att(nData):
   if nData['targets'] == 0:
       return .01
   else:
       return nData['targets']
roll_wr_recs['rec_targets'] = roll_wr_recs.apply(lambda df: pass_att(df), axis=1)   


def game_pff(data=None):
    pff_cols = data.filter(like='grades_').columns.tolist()
    recrat_cols = data.filter(regex=r'avg_depth_of_target|yprr|yards_|targeted_qb_rating|drop_rate|drops|contested_|caught_|avoid_').columns.tolist()
    pff_cols = pff_cols+recrat_cols
    group = data.groupby(data['unique_team_id'])[pff_cols].mean()
    return group

roll_wr_pffs = game_pff(data=roll_wr_recs)
Fant_colmean = str('_'+'recrollavgs')
roll_wr_pffs.rename(columns=lambda x: x+Fant_colmean, inplace=True)
roll_wr_pffs.reset_index(inplace=True)

roll_te_pffs = game_pff(data=roll_te_rec)
Fant_colmean = str('_'+'te_recrollavgs')
roll_te_pffs.rename(columns=lambda x: x+Fant_colmean, inplace=True)
roll_te_pffs.reset_index(inplace=True)

roll_rb_pffs = game_pff(data=roll_rb_rec)
Fant_colmean = str('_'+'rb_recrollavgs')
roll_rb_pffs.rename(columns=lambda x: x+Fant_colmean, inplace=True)
roll_rb_pffs.reset_index(inplace=True)


def weighted(nData, snap_Var='targets'):
    pff_cols = nData.filter(like='grades_').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)

def pros(nData, snap_Var='targets'):
    pro_cols = nData.filter(regex='height|wt|speed|draft_yr|round|selection').columns
    return pd.Series(np.average(nData[pro_cols], weights=nData[snap_Var], axis=0), pro_cols)

roll_wrs_avgs=roll_wr_recs.fillna(roll_wr_recs.mean())
wr_pro_avgs = roll_wrs_avgs.groupby('unique_team_id').apply(pros).reset_index()
roll_te_avgs=roll_te_rec.fillna(roll_te_rec.mean())
te_pro_avgs = roll_te_avgs.groupby('unique_team_id').apply(pros).reset_index()

roll_wrs_zeros=roll_wr_recs.fillna(0.1)
#roll_rbs_zeros=roll_rb_avgs.fillna(0.1)
roll_tes_zeros=roll_te_avgs.fillna(0.1)

wr_pff_targ_avgs = roll_wrs_zeros.groupby('unique_team_id').apply(weighted).reset_index()
te_pff_targ_avgs = roll_tes_zeros.groupby('unique_team_id').apply(weighted).reset_index()
#rb_pff_targ_avgs = roll_rbs_zeros.groupby('unique_team_id').apply(weighted).reset_index()

roll_wr_recs = game_combine(data=roll_wr_recs)
roll_te_rec = game_combine(data=roll_te_rec)
roll_rb_rec = game_combine(data=roll_rb_rec)

wr_stats = pd.merge(roll_wr_pffs, wr_pro_avgs, on='unique_team_id', how='left').merge(wr_pff_targ_avgs, on='unique_team_id', how='left').merge(roll_wr_recs, on='unique_team_id', how='left')
wr_stats.head()
# Out:
#   unique_team_id  grades_hands_drop_recrollavgs  \
# 0    ari_2006_10                      65.533333
# 1    ari_2006_11                      62.883333
# 2    ari_2006_12                      59.516667
# 3    ari_2006_13                      61.016667
# 4    ari_2006_14                      59.066667
#
#    grades_hands_fumble_recrollavgs  grades_offense_recrollavgs  \
# 0                        66.755556                   68.533333
# 1                        65.991667                   65.091667
# 2                        65.483333                   66.083333
# 3                        66.716839                   67.991667
# 4                        66.083506                   67.650000
#
#    grades_pass_block_recrollavgs  grades_pass_route_recrollavgs  \
# 0                      64.827716                      68.211111
# 1                      64.827716                      64.558333
# 2                      64.827716                      65.591667
# 3                      64.827716                      67.600000
# 4                      64.827716                      67.616667
#
#    avg_depth_of_target_recrollavgs  caught_percent_recrollavgs  \
# 0                        11.100000                   55.233333
# 1                        12.191667                   57.050000
# 2                        11.300000                   64.983333
# 3                        13.733333                   61.466667
# 4                        12.833333                   66.600000
#
#    contested_catch_rate_recrollavgs  contested_receptions_recrollavgs  ...  \
# 0                         46.178113                               0.0  ...
# 1                         46.178113                               0.0  ...
# 2                         46.178113                               0.0  ...
# 3                         46.178113                               0.0  ...
# 4                         46.178113                               0.0  ...
#
#      targets  touchdowns   wide_rate  wide_snaps       yards  \
# 0  24.000000    1.333333  218.400000   78.000000  168.666667
# 1  26.333333    0.666667  241.133333   83.000000  187.333333
# 2  21.333333    1.000000  237.633333   77.666667  164.333333
# 3  27.666667    1.000000  226.200000   89.000000  248.000000
# 4  24.000000    1.000000  209.833333   77.000000  218.000000
#
#    yards_after_catch  yards_after_catch_per_reception  yards_per_reception  \
# 0          70.000000                        16.966667            40.166667
# 1          52.333333                        16.466667            59.266667
# 2          42.666667                        14.133333            54.366667
# 3          55.666667                        13.299498            56.707783
# 4          47.666667                        11.932831            52.241116
#
#        yprr  rec_targets
# 0  4.836667    24.000000
# 1  5.676667    26.333333
# 2  5.700000    21.333333
# 3  6.703333    27.666667
# 4  6.910000    24.000000
#
# [5 rows x 65 columns]

# %%
te_stats = pd.merge(roll_te_pffs, te_pro_avgs, on='unique_team_id', how='left').merge(te_pff_targ_avgs, on='unique_team_id', how='left').merge(roll_te_rec, on='unique_team_id', how='left')
te_stats.head()
# Out:
#   unique_team_id  grades_hands_drop_te_recrollavgs  \
# 0    ari_2006_10                         56.748893
# 1    ari_2006_11                         58.690837
# 2    ari_2006_12                         60.274723
# 3    ari_2006_13                         62.000000
# 4    ari_2006_14                         60.658057
#
#    grades_hands_fumble_te_recrollavgs  grades_offense_te_recrollavgs  \
# 0                           63.534712                      55.550000
# 1                           64.084367                      53.466667
# 2                           63.383678                      56.350000
# 3                           54.916667                      51.350000
# 4                           54.833678                      54.066667
#
#    grades_pass_block_te_recrollavgs  grades_pass_route_te_recrollavgs  \
# 0                         63.059239                         49.466667
# 1                         49.925905                         51.933333
# 2                         53.400000                         53.116667
# 3                         44.433333                         52.450000
# 4                         63.771286                         53.150000
#
#    avg_depth_of_target_te_recrollavgs  caught_percent_te_recrollavgs  \
# 0                            3.500000                      25.000000
# 1                            3.833333                      41.666667
# 2                            3.000000                      75.000000
# 3                            3.000000                      95.833333
# 4                            3.916667                      79.166667
#
#    contested_catch_rate_te_recrollavgs  contested_receptions_te_recrollavgs  \
# 0                            46.178113                                  0.0
# 1                            46.178113                                  0.0
# 2                            46.178113                                  0.0
# 3                            46.178113                                  0.0
# 4                            46.178113                                  0.0
#
#    ...  targeted_qb_rating   targets  touchdowns  wide_rate  wide_snaps  \
# 0  ...          104.200000  2.333333         0.0   1.433333    0.333333
# 1  ...          118.766667  3.666667         0.0   2.766667    0.666667
# 2  ...          161.133333  4.000000         0.0   4.666667    0.666667
# 3  ...          177.100000  4.666667         0.0   4.666667    0.666667
# 4  ...          163.900000  3.666667         0.0  11.666667    0.666667
#
#        yards  yards_after_catch  yards_after_catch_per_reception  \
# 0  10.333333           5.666667                        12.997993
# 1  19.666667          10.000000                        11.498494
# 2  23.666667          12.000000                         9.166165
# 3  27.666667          10.000000                         4.433333
# 4  22.000000           6.333333                         5.099498
#
#    yards_per_reception      yprr
# 0            25.164466  0.960000
# 1            22.790016  1.093333
# 2            17.707783  1.630000
# 3            10.900000  1.923333
# 4            13.607783  1.956667
#
# [5 rows x 64 columns]

# %%
rb_rec_stats = pd.merge(roll_rb_pffs, roll_rb_rec, on='unique_team_id', how='left')
rb_rec_stats.head()
# Out:
#   unique_team_id  grades_hands_drop_rb_recrollavgs  \
# 0    ari_2006_10                         55.938889
# 1    ari_2006_11                         62.466667
# 2    ari_2006_12                         66.974723
# 3    ari_2006_13                         68.300000
# 4    ari_2006_14                         64.916113
#
#    grades_hands_fumble_rb_recrollavgs  grades_offense_rb_recrollavgs  \
# 0                           63.683908                      51.811111
# 1                           62.778007                      55.300000
# 2                           62.383678                      59.050000
# 3                           48.833333                      61.333333
# 4                           65.283678                      57.516667
#
#    grades_pass_block_rb_recrollavgs  grades_pass_route_rb_recrollavgs  \
# 0                         69.567874                         55.205556
# 1                         64.328381                         62.555556
# 2                         66.950000                         61.483333
# 3                         77.366667                         64.500000
# 4                         65.404619                         58.533333
#
#    avg_depth_of_target_rb_recrollavgs  caught_percent_rb_recrollavgs  \
# 0                            0.722222                      59.255556
# 1                            1.466667                      62.955556
# 2                            1.450000                      58.333333
# 3                            2.300000                      66.666667
# 4                            0.366667                      61.116667
#
#    contested_catch_rate_rb_recrollavgs  contested_receptions_rb_recrollavgs  \
# 0                            46.178113                                  0.0
# 1                            46.178113                                  0.0
# 2                            46.178113                                  0.0
# 3                            46.178113                                  0.0
# 4                            46.178113                                  0.0
#
#    ...  targeted_qb_rating   targets  touchdowns  wide_rate  wide_snaps  \
# 0  ...          204.300000  6.000000         0.0        0.0    0.000000
# 1  ...          200.700000  8.000000         0.0        0.0    0.000000
# 2  ...          129.866667  6.333333         0.0        0.0    0.000000
# 3  ...           69.933333  3.666667         0.0        1.5    0.333333
# 4  ...          136.366667  3.000000         0.0        1.5    0.333333
#
#        yards  yards_after_catch  yards_after_catch_per_reception  \
# 0  23.500000          19.000000                        14.148745
# 1  28.000000          24.000000                        14.399498
# 2  21.333333          19.333333                        10.899498
# 3  12.333333           9.000000                         4.500000
# 4  10.333333           8.333333                         9.498996
#
#    yards_per_reception      yprr
# 0            22.202791  4.360000
# 1            19.307783  4.626667
# 2            13.641116  1.650000
# 3             6.166667  0.680000
# 4            13.415566  0.796667
#
# [5 rows x 53 columns]

# %%
roll_oline.head().T
# Out:
#                                                       1  \
# unique_id                        aaronbrewer_ten_2020_5
# player_id                          aaronbrewer_ten_2020
# unique_team_id                               ten_2020_5
# team_id_impute                                 ten_2020
# player_name                                 aaronbrewer
# player_team                             aaronbrewer_ten
# player                                      aaronbrewer
# position                                              g
# team_name                                           ten
# player_game_count                                     1
# block_percent                                       100
# declined_penalties                                    0
# franchise_id                                         31
# grades_offense                                       60
# grades_pass_block                                  65.9
# grades_run_block                                 62.249
# hits_allowed                                          0
# hurries_allowed                                       0
# non_spike_pass_block                                  1
# non_spike_pass_block_percentage                     100
# pass_block_percent                                  100
# pbe                                                 100
# penalties                                             0
# pressures_allowed                                     0
# sacks_allowed                                         0
# snap_counts_block                                     1
# snap_counts_ce                                        0
# snap_counts_lg                                        0
# snap_counts_lt                                        0
# snap_counts_offense                                   1
# snap_counts_pass_block                                1
# snap_counts_pass_play                                 1
# snap_counts_rg                                        0
# snap_counts_rt                                        0
# snap_counts_run_block                                 0
# snap_counts_te                                        1
# week                                                  1
# year                                               2020
#
#                                                       2  \
# unique_id                        aaronbrewer_ten_2020_7
# player_id                          aaronbrewer_ten_2020
# unique_team_id                               ten_2020_7
# team_id_impute                                 ten_2020
# player_name                                 aaronbrewer
# player_team                             aaronbrewer_ten
# player                                      aaronbrewer
# position                                              g
# team_name                                           ten
# player_game_count                                     1
# block_percent                                       100
# declined_penalties                                    0
# franchise_id                                         31
# grades_offense                                       60
# grades_pass_block                               65.9273
# grades_run_block                                61.1245
# hits_allowed                                          0
# hurries_allowed                                       0
# non_spike_pass_block                                0.5
# non_spike_pass_block_percentage                 71.3499
# pass_block_percent                              71.3981
# pbe                                             98.1944
# penalties                                             0
# pressures_allowed                                     0
# sacks_allowed                                         0
# snap_counts_block                                     1
# snap_counts_ce                                        0
# snap_counts_lg                                        0
# snap_counts_lt                                        0
# snap_counts_offense                                   1
# snap_counts_pass_block                              0.5
# snap_counts_pass_play                               0.5
# snap_counts_rg                                        0
# snap_counts_rt                                        0
# snap_counts_run_block                               0.5
# snap_counts_te                                      0.5
# week                                                  3
# year                                               2020
#
#                                                        3  \
# unique_id                        aaronbrewer_ten_2020_10
# player_id                           aaronbrewer_ten_2020
# unique_team_id                               ten_2020_10
# team_id_impute                                  ten_2020
# player_name                                  aaronbrewer
# player_team                              aaronbrewer_ten
# player                                       aaronbrewer
# position                                               g
# team_name                                            ten
# player_game_count                                      1
# block_percent                                        100
# declined_penalties                                     0
# franchise_id                                          31
# grades_offense                                        60
# grades_pass_block                                65.9364
# grades_run_block                                  60.283
# hits_allowed                                           0
# hurries_allowed                                        0
# non_spike_pass_block                            0.333333
# non_spike_pass_block_percentage                  61.7998
# pass_block_percent                               61.8641
# pbe                                              97.5926
# penalties                                              0
# pressures_allowed                                      0
# sacks_allowed                                          0
# snap_counts_block                                      1
# snap_counts_ce                                         0
# snap_counts_lg                                         0
# snap_counts_lt                                         0
# snap_counts_offense                                    1
# snap_counts_pass_block                          0.333333
# snap_counts_pass_play                           0.333333
# snap_counts_rg                                         0
# snap_counts_rt                                         0
# snap_counts_run_block                           0.666667
# snap_counts_te                                  0.666667
# week                                             4.33333
# year                                                2020
#
#                                                        4  \
# unique_id                        aaronbrewer_ten_2020_11
# player_id                           aaronbrewer_ten_2020
# unique_team_id                               ten_2020_11
# team_id_impute                                  ten_2020
# player_name                                  aaronbrewer
# player_team                              aaronbrewer_ten
# player                                       aaronbrewer
# position                                               g
# team_name                                            ten
# player_game_count                                      1
# block_percent                                        100
# declined_penalties                                     0
# franchise_id                                          31
# grades_offense                                   70.2667
# grades_pass_block                                65.9546
# grades_run_block                                    68.3
# hits_allowed                                           0
# hurries_allowed                                        0
# non_spike_pass_block                                   0
# non_spike_pass_block_percentage                  42.6997
# pass_block_percent                               42.7962
# pbe                                              96.3889
# penalties                                              0
# pressures_allowed                                      0
# sacks_allowed                                          0
# snap_counts_block                                      3
# snap_counts_ce                                         0
# snap_counts_lg                                         2
# snap_counts_lt                                         0
# snap_counts_offense                                    3
# snap_counts_pass_block                                 0
# snap_counts_pass_play                                  0
# snap_counts_rg                                         0
# snap_counts_rt                                         0
# snap_counts_run_block                                  3
# snap_counts_te                                  0.666667
# week                                             7.33333
# year                                                2020
#
#                                                        5
# unique_id                        aaronbrewer_ten_2020_12
# player_id                           aaronbrewer_ten_2020
# unique_team_id                               ten_2020_12
# team_id_impute                                  ten_2020
# player_name                                  aaronbrewer
# player_team                              aaronbrewer_ten
# player                                       aaronbrewer
# position                                               g
# team_name                                            ten
# player_game_count                                      1
# block_percent                                        100
# declined_penalties                                     0
# franchise_id                                          31
# grades_offense                                   75.6333
# grades_pass_block                                65.4031
# grades_run_block                                    73.4
# hits_allowed                                    0.333333
# hurries_allowed                                        0
# non_spike_pass_block                                  12
# non_spike_pass_block_percentage                  61.7998
# pass_block_percent                               61.8641
# pbe                                              97.1259
# penalties                                              0
# pressures_allowed                               0.333333
# sacks_allowed                                          0
# snap_counts_block                                     26
# snap_counts_ce                                         0
# snap_counts_lg                                   25.3333
# snap_counts_lt                                         0
# snap_counts_offense                                   26
# snap_counts_pass_block                           12.6667
# snap_counts_pass_play                            12.6667
# snap_counts_rg                                         0
# snap_counts_rt                                         0
# snap_counts_run_block                            13.3333
# snap_counts_te                                  0.666667
# week                                             9.33333
# year                                                2020

# %% [markdown]
# ### OL Position Weights and Stats Groupby's

# %%
roll_oline.columns
# Out:
# Index(['unique_id', 'player_id', 'unique_team_id', 'team_id_impute',
#        'player_name', 'player_team', 'player', 'position', 'team_name',
#        'player_game_count', 'block_percent', 'declined_penalties',
#        'franchise_id', 'grades_offense', 'grades_pass_block',
#        'grades_run_block', 'hits_allowed', 'hurries_allowed',
#        'non_spike_pass_block', 'non_spike_pass_block_percentage',
#        'pass_block_percent', 'pbe', 'penalties', 'pressures_allowed',
#        'sacks_allowed', 'snap_counts_block', 'snap_counts_ce',
#        'snap_counts_lg', 'snap_counts_lt', 'snap_counts_offense',
#        'snap_counts_pass_block', 'snap_counts_pass_play', 'snap_counts_rg',
#        'snap_counts_rt', 'snap_counts_run_block', 'snap_counts_te', 'week',
#        'year'],
#       dtype='object')

# %%
ol_df.columns = [str(col) + '_ols' for col in ol_df.columns]
roll_oline = pd.merge(roll_oline, ol_df, left_on='player_id', right_on='unique_id_ols', how='left')

roll_oline.drop_duplicates(subset=['unique_id'], keep='first', inplace=True)


def snap_fix(nData, var=None):
    if nData[var] == 0:
        return .1
    else:
        return nData[var]

roll_oline['snap_counts_offense'] = roll_oline.apply(lambda df: snap_fix(df, var='snap_counts_offense'), axis=1)
roll_oline['snap_counts_pass_block'] = roll_oline.apply(lambda df: snap_fix(df, var='snap_counts_pass_block'), axis=1) 
roll_oline['snap_counts_run_block'] = roll_oline.apply(lambda df: snap_fix(df, var='snap_counts_run_block'), axis=1) 


def weighted(nData, snap_Var='snap_counts_offense'):
    pff_cols = nData.filter(like='grades_').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)
ol_pff_off = roll_oline.groupby('unique_team_id').apply(weighted).reset_index()

def weighted(nData, snap_Var='snap_counts_pass_block'):
    pff_cols = nData.filter(like='grades_pass_block').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)
ol_pff_pass = roll_oline.groupby('unique_team_id').apply(weighted).reset_index()

def weighted(nData, snap_Var='snap_counts_run_block'):
    pff_cols = nData.filter(like='grades_run_block').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)
ol_pff_run = roll_oline.groupby('unique_team_id').apply(weighted).reset_index()

def pros(nData, snap_Var='snap_counts_offense'):
    pro_cols = nData.filter(regex='height|wt|speed|draft_yr|round|selection').columns
    return pd.Series(np.average(nData[pro_cols], weights=nData[snap_Var], axis=0), pro_cols)


roll_oline_avgs=roll_oline.fillna(roll_oline.mean())
roll_oline_avgs = roll_oline_avgs.groupby('unique_team_id').apply(pros).reset_index()

ol_sums = game_combine(data=roll_oline)

ol_stats = pd.merge(ol_pff_off, roll_oline_avgs, on='unique_team_id', how='left').merge(ol_sums, on='unique_team_id', how='left').merge(ol_pff_pass, on='unique_team_id', how='left').merge(ol_pff_run, on='unique_team_id', how='left')				
ol_stats.head()
# Out:
#   unique_team_id  grades_offense  grades_pass_block_x  grades_run_block_x  \
# 0    ari_2006_10       63.512075            68.274935           62.075212
# 1    ari_2006_11       63.275788            67.605292           61.416593
# 2    ari_2006_12       63.991576            67.794372           61.601561
# 3    ari_2006_13       59.184875            66.463236           57.273862
# 4    ari_2006_14       61.760000            67.420000           59.533333
#
#    height_ols      wt_ols  speed_ols  draft_yr_ols  round_ols  selection_ols  \
# 0   76.276274  325.671975   5.269813   2001.595541   5.413217     151.570860
# 1   76.064835  327.285714   5.266378   2002.769231   4.961538     136.130769
# 2   76.000000  328.067538   5.280292   2003.248366   4.798475     130.846405
# 3   76.004405  327.916300   5.279089   2003.211454   4.856828     132.746696
# 4   76.000000  327.600000   5.277465   2003.200000   5.000000     137.400000
#
#    ...  snap_counts_lt  snap_counts_offense  snap_counts_pass_block  \
# 0  ...       68.666667           418.666667              247.833333
# 1  ...       62.000000           303.333333              197.666667
# 2  ...       63.666667           306.000000              192.666667
# 3  ...       62.000000           302.666667              218.433333
# 4  ...       63.000000           315.000000              198.333333
#
#    snap_counts_pass_play  snap_counts_rg  snap_counts_rt  \
# 0             248.166667      143.333333       68.666667
# 1             198.000000       85.333333       62.000000
# 2             192.666667       82.333333       63.666667
# 3             218.333333       62.000000       62.000000
# 4             198.333333       63.000000       63.000000
#
#    snap_counts_run_block  snap_counts_te  grades_pass_block_y  \
# 0             170.833333        0.666667            68.433870
# 1             105.666667        1.000000            67.669389
# 2             113.333333        0.000000            67.769089
# 3              84.333333        1.333333            66.472282
# 4             116.666667        0.000000            67.420000
#
#    grades_run_block_y
# 0           62.074049
# 1           61.440904
# 2           61.577745
# 3           57.305138
# 4           59.533333
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Defensive Position Weights and Stats Groupby's

# %%
def_lineman.columns
# Out:
# Index(['unique_id', 'player_id', 'unique_team_id', 'team_id_impute',
#        'player_name', 'player_team', 'player', 'position', 'team_name',
#        'player_game_count', 'assists', 'batted_passes', 'catch_rate',
#        'declined_penalties', 'forced_fumbles', 'franchise_id',
#        'grades_coverage_defense', 'grades_defense', 'grades_defense_penalty',
#        'grades_pass_rush_defense', 'grades_run_defense', 'grades_tackle',
#        'hits', 'hurries', 'interceptions', 'longest', 'missed_tackle_rate',
#        'missed_tackles', 'pass_break_ups', 'penalties', 'qb_rating_against',
#        'receptions', 'sacks', 'snap_counts_box', 'snap_counts_corner',
#        'snap_counts_coverage', 'snap_counts_defense', 'snap_counts_dl',
#        'snap_counts_dl_a_gap', 'snap_counts_dl_b_gap',
#        'snap_counts_dl_outside_t', 'snap_counts_dl_over_t', 'snap_counts_fs',
#        'snap_counts_offball', 'snap_counts_pass_rush',
#        'snap_counts_run_defense', 'snap_counts_slot', 'stops', 'tackles',
#        'targets', 'total_pressures', 'touchdowns', 'yards',
#        'yards_after_catch', 'yards_per_reception', 'week', 'year'],
#       dtype='object')

# %%
	   
def_lb.columns = [str(col) + '_def_lbs' for col in def_lb.columns]
def_linebackers = pd.merge(def_linebackers, def_lb, left_on='player_id', right_on='unique_id_def_lbs', how='left')
def_linebackers.drop_duplicates(subset=['unique_id'], keep='first', inplace=True)

def_dl.columns = [str(col) + '_def_dls' for col in def_dl.columns]
def_lineman = pd.merge(def_lineman, def_dl, left_on='player_id', right_on='unique_id_def_dls', how='left')
def_lineman.drop_duplicates(subset=['unique_id'], keep='first', inplace=True)

def_db.columns = [str(col) + '_def_dbs' for col in def_db.columns]
def_dbs = pd.merge(def_dbs, def_db, left_on='player_id', right_on='unique_id_def_dbs', how='left')
def_dbs.drop_duplicates(subset=['unique_id'], keep='first', inplace=True)

	   
def snap_fixs(nData, var=None):
    if nData[var] == 0:
        return 1
    else:
        return nData[var]
roll_defense['snap_counts_defense'] = roll_defense.apply(lambda df: snap_fixs(df, var='snap_counts_defense'), axis=1) 
roll_defense['snap_counts_run_defense'] = roll_defense.apply(lambda df: snap_fixs(df, var='snap_counts_run_defense'), axis=1) 
roll_defense['snap_counts_pass_rush'] = roll_defense.apply(lambda df: snap_fixs(df, var='snap_counts_pass_rush'), axis=1) 
roll_defense['snap_counts_coverage'] = roll_defense.apply(lambda df: snap_fixs(df, var='snap_counts_coverage'), axis=1) 

def_linebackers['snap_counts_defense'] = def_linebackers.apply(lambda df: snap_fixs(df, var='snap_counts_defense'), axis=1) 
def_lineman['snap_counts_defense'] = def_lineman.apply(lambda df: snap_fixs(df, var='snap_counts_defense'), axis=1) 
def_dbs['snap_counts_defense'] = def_dbs.apply(lambda df: snap_fixs(df, var='snap_counts_defense'), axis=1) 


def weighted(nData, snap_Var='snap_counts_defense'):
    pff_cols = nData.filter(like='grades_').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)
def_pff_avg = roll_defense.groupby('unique_team_id').apply(weighted).reset_index()

def weighted(nData, snap_Var='snap_counts_run_defense'):
    pff_cols = nData.filter(like='grades_run_defense').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)
def_pff_rush = roll_defense.groupby('unique_team_id').apply(weighted).reset_index()

def weighted(nData, snap_Var='snap_counts_pass_rush'):
    pff_cols = nData.filter(like='grades_pass_rush_defense').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)
def_pff_passrush = roll_defense.groupby('unique_team_id').apply(weighted).reset_index()

def weighted(nData, snap_Var='snap_counts_coverage'):
    pff_cols = nData.filter(like='grades_coverage_defense').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)
def_pff_cov = roll_defense.groupby('unique_team_id').apply(weighted).reset_index()

def_sums = game_combine(data=roll_defense)

def_stats = pd.merge(def_pff_avg, def_pff_rush, on='unique_team_id', how='inner').merge(def_pff_passrush, on='unique_team_id', how='inner').merge(def_pff_cov, on='unique_team_id', how='inner').merge(def_sums, on='unique_team_id', how='inner')

def posgroup_weighted(nData, snap_Var='snap_counts_defense'):
    pff_cols = nData.filter(like='grades_').columns
    return pd.Series(np.average(nData[pff_cols], weights=nData[snap_Var], axis=0), pff_cols)


def pros(nData, snap_Var='snap_counts_defense'):
    pro_cols = nData.filter(regex='height|wt|speed|draft_yr|round|selection').columns
    return pd.Series(np.average(nData[pro_cols], weights=nData[snap_Var], axis=0), pro_cols)


def_linebackers_avgs=def_linebackers.fillna(def_linebackers.mean())
def_linebackers_avgs = def_linebackers_avgs.groupby('unique_team_id').apply(pros).reset_index()

def_lineman_avgs=def_lineman.fillna(def_lineman.mean())
def_lineman_avgs = def_lineman_avgs.groupby('unique_team_id').apply(pros).reset_index()

def_dbs_avgs=def_dbs.fillna(def_dbs.mean())
def_dbs_avgs = def_dbs_avgs.groupby('unique_team_id').apply(pros).reset_index()


lbs_pff_avg = def_linebackers.groupby('unique_team_id').apply(posgroup_weighted)
Fant_colmean = str('_'+'lbs_pff_avgs')
lbs_pff_avg.rename(columns=lambda x: x+Fant_colmean, inplace=True)
lbs_pff_avg = lbs_pff_avg.reset_index()

dl_pff_avg = def_lineman.groupby('unique_team_id').apply(posgroup_weighted)				
Fant_colmean = str('_'+'dls_pff_avgs')
dl_pff_avg.rename(columns=lambda x: x+Fant_colmean, inplace=True)
dl_pff_avg = dl_pff_avg.reset_index()

dbs_pff_avg = def_dbs.groupby('unique_team_id').apply(posgroup_weighted)				
Fant_colmean = str('_'+'dbs_pff_avgs')
dbs_pff_avg.rename(columns=lambda x: x+Fant_colmean, inplace=True)
dbs_pff_avg = dbs_pff_avg.reset_index()
# Out:
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
spread_comb.columns
# Out:
# Index(['home_matchup_id', 'away_matchup_id', 'team_id', 'schedule_date',
#        'schedule_season', 'schedule_week', 'team_home_abb', 'score_home',
#        'score_away', 'away_team_abb', 'team_favorite_id', 'spread_favorite',
#        'over_under_line', 'fav_spread', 'team_notfav_id', 'fav_cover',
#        'over_under_result', 'precip', 'dome', 'temperature', 'wind_mph',
#        'team_abb', 'fav_homeoraway', 'team_ids', 'team_conference',
#        'team_division', 'team', 'w-l', 'year', 'week', 'off_dvoa_rank',
#        'off_dvoa', 'off_weight_dvoa_rank', 'off_weight_dvoa', 'pass_off_rank',
#        'pass_off', 'rush_off_rank', 'rush_off', 'def_dvoa_rank', 'def_dvoa',
#        'def_weight_dvoa_rank', 'def_weight_dvoa', 'pass_def_rank', 'pass_def',
#        'rush_def_rank', 'rush_def', 'off_dvoa_momentum',
#        'off_wt_dvoa_momentum', 'pass_off_dvoa_momentum',
#        'rush_off_dvoa_momentum', 'def_dvoa_momentum', 'def_wt_dvoa_momentum',
#        'pass_def_dvoa_momentum', 'rush_dvoa_momentum'],
#       dtype='object')

# %% [markdown]
# ### Bring all of these together into one line to represent a team_year_week momentum indicator

# %%
from functools import reduce

spread_vars = spread_comb[spread_comb['schedule_week'] != '1']
spread_ids = spread_vars[['team_id', 'home_matchup_id']]
spread_ids.columns = ['unique_team_id','home_matchup_id']
spread_targs = spread_vars[['team_id','schedule_week','schedule_season','home_matchup_id','team_favorite_id','spread_favorite','over_under_line','fav_cover','over_under_result']]
spread_divs = spread_vars[['team_id','fav_homeoraway','team_conference','team_division',
                          "temperature",
                          "wind_mph",
                          "dome",
                          "precip"]]
spread_dvoa= spread_vars[['team_id','off_dvoa_rank',
       'off_dvoa', 'off_weight_dvoa_rank', 'off_weight_dvoa', 'pass_off_rank',
       'pass_off', 'rush_off_rank', 'rush_off', 'def_dvoa_rank', 'def_dvoa',
       'def_weight_dvoa_rank', 'def_weight_dvoa', 'pass_def_rank', 'pass_def',
       'rush_def_rank', 'rush_def','off_dvoa_momentum',
       'off_wt_dvoa_momentum', 'pass_off_dvoa_momentum',
       'rush_off_dvoa_momentum', 'def_dvoa_momentum', 'def_wt_dvoa_momentum',
       'pass_def_dvoa_momentum', 'rush_dvoa_momentum']]
spread_dvoa.rename(columns={'team_id':'unique_team_id'}, inplace=True)
#'fav_conf_game','fav_div_game',
dfs_list = [spread_ids,
            spread_dvoa,
            tgs_roll,
            qb_stats,
            qb_rush_stats,
            wr_stats,
            rb_stats,
            rb_rec_stats,
            te_stats,
            ol_stats,
            dbs_pff_avg,
            dl_pff_avg,
            lbs_pff_avg,
            def_linebackers_avgs,
            def_lineman_avgs,
            def_dbs_avgs,
            def_stats]

dfs_team = reduce(lambda  left,right: pd.merge(left,right,on=['unique_team_id'],
                                            how='left'), dfs_list)

def fav_ids(nData):
    if str(nData['team_favorite_id']) in str(nData['team_id']):
        return nData['team_id']
    else:
        pass
spread_targs['fav_team_id'] = spread_targs.apply(lambda nData: fav_ids(nData), axis=1)


favs = spread_targs[~spread_targs['fav_team_id'].isnull()]
not_fav = spread_targs[spread_targs['fav_team_id'].isnull()]

not_fav_df = dfs_team[dfs_team.unique_team_id.isin(not_fav.team_id)]

favs = favs[['team_id','schedule_week','schedule_season','spread_favorite','over_under_line','fav_cover','over_under_result']]
not_fav = not_fav[['team_id','schedule_week','schedule_season','spread_favorite','over_under_line','fav_cover','over_under_result']]


fin_df = pd.merge(favs, dfs_team, left_on='team_id', right_on='unique_team_id', how='left').merge(not_fav_df, on='home_matchup_id', how='left').merge(spread_divs, on='team_id', how='left')
# Out:
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from functools import reduce

spread_targs = spread_vars[['team_id','schedule_week','schedule_season','team_favorite_id','spread_favorite','over_under_line','over_under_result']]
spread_targs.rename(columns={'team_id':'unique_team_id'}, inplace=True)
spread_divs = spread_vars[['team_id','fav_homeoraway',
                          "temperature",
                          "wind_mph",
                          "dome",
                          "precip"]]


defs_pff_list = [spread_ids,
            tgs_roll,
            qb_stats,
            qb_rush_stats,
            wr_stats,
            rb_stats,
            rb_rec_stats,
            te_stats,
            ol_stats,
            dbs_pff_avg,
            dl_pff_avg,
            lbs_pff_avg,
            def_linebackers_avgs,
            def_lineman_avgs,
            def_dbs_avgs,
            def_stats]

defs_team = reduce(lambda  left,right: pd.merge(left,right,on=['unique_team_id'],
                                            how='left'), defs_pff_list)

def fav_ids(nData):
    if str(nData['team_favorite_id']) in str(nData['unique_team_id']):
        return nData['unique_team_id']
    else:
        pass
spread_targs['fav_team_id'] = spread_targs.apply(lambda nData: fav_ids(nData), axis=1)

favs = spread_targs[~spread_targs['fav_team_id'].isnull()]
favs['over_under_line'] = (favs['over_under_line'].apply(float))
favs['spread_favorite'] = (favs['spread_favorite'].apply(float))
favs['implied_score'] = (favs['over_under_line']/2)-favs['spread_favorite']

not_fav = spread_targs[spread_targs['fav_team_id'].isnull()]
not_fav['over_under_line'] = (not_fav['over_under_line'].apply(float))
not_fav['spread_favorite'] = (not_fav['spread_favorite'].apply(float))
not_fav['spread_favorite'] = (not_fav['spread_favorite']*-1)
not_fav['implied_score'] = (not_fav['over_under_line']/2)-not_fav['spread_favorite']


favs = favs[['unique_team_id','schedule_week','schedule_season','spread_favorite','over_under_line','over_under_result','implied_score']]
not_fav = not_fav[['unique_team_id','schedule_week','schedule_season','spread_favorite','over_under_line','over_under_result','implied_score']]

comb = pd.concat([favs, not_fav], axis=0)

OU_df = pd.merge(comb, defs_team, on='unique_team_id', how='left').merge(defs_team, on='opponent_id_overall_pff', how='left')
# Out:
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/tom/anaconda3/envs/cloak/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
not_fav['implied_score2'] = (not_fav['over_under_line']/2)-not_fav['spread_favorite']
not_fav.head(n=5)
# Out:
#    unique_team_id schedule_week schedule_season  spread_favorite  \
# 19      sf_2006_2             2            2006              3.0
# 22      gb_2006_2             2            2006              1.0
# 25     nyj_2006_2             2            2006              6.0
# 30     jax_2006_2             2            2006              2.5
# 35      no_2006_3             3            2006              4.0
#
#     over_under_line over_under_result  implied_score  implied_score2
# 19             44.5             under          19.25           19.25
# 22             40.5              over          19.25           19.25
# 25             38.5              over          13.25           13.25
# 30             36.5             under          15.75           15.75
# 35             45.0             under          18.50           18.50

# %%
OU_df.tail(n=5).T
# Out:
#                               10701       10702       10703       10704  \
# unique_team_id_x         ari_2021_4  sea_2021_4  bal_2021_4  pit_2021_4
# schedule_week                     4           4           4           4
# schedule_season                2021        2021        2021        2021
# spread_favorite                 4.5           3           1           7
# over_under_line                54.5          52        44.5        45.5
# ...                             ...         ...         ...         ...
# total_pressures_y           17.8333     19.6667     18.8333     16.1667
# touchdowns_y                1.66667     1.66667     1.66667           2
# yards_y                       228.5     314.333       314.5     279.667
# yards_after_catch_y_y       105.833     147.833     183.167     106.333
# yards_per_reception_y_y     208.502      217.81     239.782     231.856
#
#                              10705
# unique_team_id_x         lv_2021_4
# schedule_week                    4
# schedule_season               2021
# spread_favorite                3.5
# over_under_line               52.5
# ...                            ...
# total_pressures_y               26
# touchdowns_y              0.833333
# yards_y                    229.667
# yards_after_catch_y_y      123.833
# yards_per_reception_y_y     213.84
#
# [953 rows x 5 columns]

# %%
OU_df['overall_perf_by_overall_perf'] = OU_df['overall_performance_overall_pff_x']/OU_df['overall_performance_overall_pff_y']
OU_df['overall_off_vs_overall_def'] = OU_df['offense_overall_pff_x']/OU_df['defense_overall_pff_y']
OU_df['overall_pass_vs_overall_coverage'] = OU_df['pass_overall_pff_x']/OU_df['coverage_overall_pff_y']
OU_df['overall_passblock_vs_overall_passrush'] = OU_df['pass_blocking_overall_pff_x']/OU_df['pass_rush_overall_pff_y']
OU_df['overall_rec_vs_overall_coverage'] = OU_df['receiving_overall_pff_x']/OU_df['coverage_overall_pff_y']
OU_df['overall_rush_vs_overall_rushdef'] = OU_df['rushing_overall_pff_x']/OU_df['rush_defense_overall_pff_y']
OU_df['overall_runblocking_vs_overall_rushdef'] = OU_df['run_blocking_overall_pff_x']/OU_df['rush_defense_overall_pff_y']
OU_df['overall_rush_vs_overall_tackling'] = OU_df['rushing_overall_pff_x']/OU_df['tackling_overall_pff_y']
OU_df['overall_tackling_vs_overall_tackling'] = OU_df['tackling_overall_pff_x']/OU_df['tackling_overall_pff_y']
OU_df['overall_off_vs_overall_off'] = OU_df['offense_overall_pff_x']/OU_df['offense_overall_pff_y']
OU_df['overall_def_vs_overall_def'] = OU_df['defense_overall_pff_x']/OU_df['defense_overall_pff_y']
OU_df['overall_passrush_vs_overall_passrush'] = OU_df['pass_rush_overall_pff_x']/OU_df['pass_rush_overall_pff_y']

# %%
OU_df = OU_df.drop_duplicates(subset=['unique_team_id_x'], keep='first')
OU_df=OU_df.round(2)
OU_df.tail(n=2).T
OU_df.to_csv(cur_dir+'/modeling_datasets/fin_df_week'+cur_week+'_OUv1.csv', index=False)

# %% [markdown]
# spread_vars = spread_comb[spread_comb['schedule_week'] != '1']
# spread_ids = spread_vars[['team_id', 'home_matchup_id']]
# spread_ids.columns = ['unique_team_id','home_matchup_id']
# spread_targs = spread_vars[['team_id','schedule_week','schedule_season','home_matchup_id','team_favorite_id','spread_favorite','over_under_line','fav_cover','over_under_result','team_home_abb','away_team_abb','score_home','score_away']]
#
# dfs_list = [spread_ids,
#             qb_stats,
#             wr_stats,
#             rb_stats,
#             ol_stats,
#             dbs_pff_avg,
#             dl_pff_avg,
#             lbs_pff_avg,
#             def_stats]
#
# defs_list = [spread_ids,
#             dbs_pff_avg,
#             dl_pff_avg,
#             lbs_pff_avg,
#             def_stats]
#
# dfs_team = reduce(lambda  left,right: pd.merge(left,right,on=['unique_team_id'],
#                                             how='left'), dfs_list)
# def_team = reduce(lambda  left,right: pd.merge(left,right,on=['unique_team_id'],
#                                             how='left'), defs_list)
#
# def team_points(nData):
#     if str(nData['team_home_abb']) in str(nData['team_id']):
#         return nData['score_home']
#     elif str(nData['away_team_abb']) in str(nData['team_id']):
#         return nData['score_away']
#     else:
#         pass
# spread_targs['team_score'] = spread_targs.apply(lambda nData: team_points(nData), axis=1)
#
# OU_df = pd.merge(spread_targs, dfs_team, left_on='team_id', right_on='unique_team_id', how='left')
# OU_df.head()

# %%
#not_fav = not_fav[['team_id','schedule_week','schedule_season','spread_favorite','over_under_line','fav_cover','over_under_result']]
#ou_df1 = pd.merge(favs, dfs_team, left_on='team_id', right_on='unique_team_id', how='left')
#ou_df2 = pd.merge(not_fav, dfs_team, left_on='team_id', right_on='unique_team_id', how='left')

#conc =pd.concat([ou_df1, ou_df2], axis=0)
##conc = conc.drop_duplicates(keep='first')
#conc.to_csv(cur_dir+'/modeling_datasets/fin_df_ou_v1.csv', index=False)

# %%
colNames = fin_df.columns[fin_df.columns.str.contains(pat = 'pff_')]
pff_dfs = fin_df[colNames]

# %% [markdown]
# ### Fav-Passing Ratio to Overall Defense and DB Performance

# %%
fin_df['fav_qb_ovr_ratio_opposing_dbs'] = fin_df['pass_pff_off_x']/fin_df['def_pff_def_dbs_pff_avgs_y']
fin_df['fav_qb_pass_ratio_opposing_dbs'] = fin_df['pass_pff_pass_x']/fin_df['def_pff_coverage_dbs_pff_avgs_y']
fin_df['fav_qb_rush_ratio_opposing_dbs'] = fin_df['pass_pff_run_x']/fin_df['def_pff_rushdef_dbs_pff_avgs_y']

fin_df['fav_qb_ovr_ratio_opposing_defs'] = fin_df['pass_pff_off_x']/fin_df['def_pff_def_y']
fin_df['fav_qb_pass_ratio_opposing_defs'] = fin_df['pass_pff_pass_x']/fin_df['def_pff_coverage_y']
fin_df['fav_qb_pass_ratio_opposing_defs'] = fin_df['pass_pff_pass_x']/fin_df['def_pff_prush_y']
fin_df['fav_qb_rush_ratio_opposing_defs'] = fin_df['pass_pff_run_x']/fin_df['def_pff_rushdef_y']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/cloak/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'pass_pff_off_x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-199d10c9f08f> in <module>
# ----> 1 fin_df['fav_qb_ovr_ratio_opposing_dbs'] = fin_df['pass_pff_off_x']/fin_df['def_pff_def_dbs_pff_avgs_y']
#       2 fin_df['fav_qb_pass_ratio_opposing_dbs'] = fin_df['pass_pff_pass_x']/fin_df['def_pff_coverage_dbs_pff_avgs_y']
#       3 fin_df['fav_qb_rush_ratio_opposing_dbs'] = fin_df['pass_pff_run_x']/fin_df['def_pff_rushdef_dbs_pff_avgs_y']
#       4
#       5 fin_df['fav_qb_ovr_ratio_opposing_defs'] = fin_df['pass_pff_off_x']/fin_df['def_pff_def_y']
#
# ~/anaconda3/envs/cloak/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/anaconda3/envs/cloak/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'pass_pff_off_x'

# %% [markdown]
# fin_df['overall_perf_by_overall_perf'] = fin_df['overall_performance_overall_pff_x']/fin_df['overall_performance_overall_pff_y']
# fin_df['overall_off_vs_overall_def'] = fin_df['offense_overall_pff_x']/fin_df['defense_overall_pff_y']
# fin_df['overall_pass_vs_overall_coverage'] = fin_df['pass_overall_pff_x']/fin_df['coverage_overall_pff_y']
# fin_df['overall_passblock_vs_overall_passrush'] = fin_df['pass_blocking_overall_pff_x']/fin_df['pass_rush_overall_pff_y']
# fin_df['overall_rec_vs_overall_coverage'] = fin_df['receiving_overall_pff_x']/fin_df['coverage_overall_pff_y']
# fin_df['overall_rush_vs_overall_rushdef'] = fin_df['rushing_overall_pff_x']/fin_df['rush_defense_overall_pff_y']
# fin_df['overall_runblocking_vs_overall_rushdef'] = fin_df['run_blocking_overall_pff_x']/fin_df['rush_defense_overall_pff_y']
# fin_df['overall_rush_vs_overall_tackling'] = fin_df['rushing_overall_pff_x']/fin_df['tackling_overall_pff_y']
# fin_df['overall_tackling_vs_overall_tackling'] = fin_df['tackling_overall_pff_x']/fin_df['tackling_overall_pff_y']
# fin_df['overall_off_vs_overall_off'] = fin_df['offense_overall_pff_x']/fin_df['offense_overall_pff_y']
# fin_df['overall_def_vs_overall_def'] = fin_df['defense_overall_pff_x']/fin_df['defense_overall_pff_y']
# fin_df['overall_passrush_vs_overall_passrush'] = fin_df['pass_rush_overall_pff_x']/fin_df['pass_rush_overall_pff_y']

# %% [markdown]
# fin_df['fav_rush_ovr_ratio_opposing_def'] = fin_df['rush_pff_off_x']/fin_df['def_pff_def_y']
# fin_df['fav_rush_run_ratio_opposing_def'] = fin_df['rush_pff_run_x']/fin_df['def_pff_rushdef_y']
# fin_df['fav_rush_ovr_ratio_opposing_dls'] = fin_df['pass_pff_off_x']/fin_df['def_pff_def_dls_pff_avgs_y']
# fin_df['fav_rush_run_ratio_opposing_dls'] = fin_df['pass_pff_pass_x']/fin_df['def_pff_rushdef_dls_pff_avgs_y']
# fin_df['fav_rush_ovr_ratio_opposing_lbs'] = fin_df['pass_pff_off_x']/fin_df['def_pff_def_lbs_pff_avgs_y']
# fin_df['fav_rush_run_ratio_opposing_lbs'] = fin_df['pass_pff_pass_x']/fin_df['def_pff_rushdef_lbs_pff_avgs_y']

# %%
fin_df=fin_df.round(2)
fin_df.tail(n=2).T
# Out:
#                       7646       7647
# team_id          kc_2021_4  tb_2021_4
# schedule_week            4          4
# schedule_season       2021       2021
# spread_favorite       -7.0       -7.0
# over_under_line       54.5       49.5
# ...                    ...        ...
# team_division     AFC West  NFC South
# temperature             67         60
# wind_mph                 6          3
# dome                     0          0
# precip                   1          0
#
# [1009 rows x 2 columns]

# %%
fin_df = fin_df.drop(['unique_team_id_x','unique_team_id_y','opponent_id_x','opponent_id_y','opponent_id_overall_pff_x','opponent_id_overall_pff_y','wl_y'], axis=1)

# %%
fin_df = fin_df.drop_duplicates(subset=['team_id'], keep='first')
fin_df.to_csv(cur_dir+'/modeling_datasets/fin_df_week'+cur_week+'_spreads_new_ats_fo_v2.csv', index=False)

# %%
spread_comb.to_csv(cur_dir+'/spead_comb.csv', index=False)
